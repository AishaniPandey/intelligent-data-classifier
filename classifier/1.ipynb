# %% [markdown]
# PART-1 KNN IMPLEMENTATION

# %%
#Below is completed 2.2.1 Task 1

 #Import the necessary library - numpy
import numpy as np

#Import the necessary library - matplotlib to plot the graph
import matplotlib.pyplot as plt

import os

# Load the dataset from the .npy file
def load_dataset(filepath):
    """
    Load the dataset from a given .npy file.
    
    Args:
    - filepath (str): Path to the .npy file.
    
    Returns:
    - np.array: Loaded data from the .npy file.
    """
    if not os.path.exists(filepath):
        raise FileNotFoundError(f"The file {filepath} does not exist.")
    
    try:
        return np.load(filepath, allow_pickle=True)
    #allow_pickle=True to remove the ValueError which is "ValueError: Cannot load file containing pickled data when allow_pickle=False"

    except Exception as e:
        raise RuntimeError(f"Error loading the dataset: {e}")

def get_label_distribution(data):
    """
    Extract the label distribution from the dataset.
    
    Args:
    - data (np.array): Loaded dataset.
    
    Returns:
    - tuple: (unique labels, counts for each label)
    """

    # Extract the label information from the dataset
    labels = data[:, 3]  # Assuming the label column is at index 3

    # Count the occurrences of each label
    return np.unique(labels, return_counts=True)

def plot_label_distribution(unique_labels, label_counts):
    """
    Plot the label distribution using a bar graph.
    
    Args:
    - unique_labels (np.array): Unique labels in the dataset.
    - label_counts (np.array): Counts for each label.
    """

    # Create a bar graph to visualize the label distribution
    plt.figure(figsize=(10, 10))
    plt.bar(unique_labels, label_counts)
    plt.xlabel('Labels')
    plt.ylabel('Count')
    plt.title('Label Distribution in the Dataset')
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()

if __name__ == "__main__":
    filepath = 'data.npy'
    data = load_dataset(filepath)
    unique_labels, label_counts = get_label_distribution(data)
    plot_label_distribution(unique_labels, label_counts)

# %% [markdown]
# Checking some basic structure of the dataset for KNN implementation

# %%
print(data.shape)  #Shape is number of outermost entries
# Out:
# (1500, 5)

# %% [markdown]
# So n=1500, thus when we will do hypertuning, it will be under root of n, that is (n)^(1/2)

# %%
print(data.size) #Checking the size
# Out:
# 7500

# %%
print(data.ndim)  #Dimension of data
# Out:
# 2

# %%
# Below is the implementation of Task 2.3.1

#Import the necessary libraries

import numpy as np
from sklearn.metrics import f1_score, accuracy_score, precision_score, recall_score
from sklearn.model_selection import train_test_split

# KNN Class Definition (Subtask 1)
class KNN:
    def __init__(self, k=3, encoder_type="resnet", distance_metric="euclidean"):
        self.k = k
        self.encoder_type = encoder_type
        self.distance_metric = distance_metric
        self.X_train = None
        self.y_train = None
        self.label_to_int = {}
        self.int_to_label = {}

#Define all the distances
    
    def _euclidean_distance(self, x1, x2):
        return np.sqrt(np.sum((x1 - x2) ** 2))
    
    def _manhattan_distance(self, x1, x2):
        return np.sum(np.abs(x1 - x2))
    
    def _cosine_distance(self, x1, x2):
        dot_product = np.dot(x1, x2)
        norm_x1 = np.linalg.norm(x1)
        norm_x2 = np.linalg.norm(x2)
        return 1 - (dot_product / (norm_x1 * norm_x2))
    
    def _hamming_distance(self, x1, x2):
        return np.sum(x1 != x2)
    
    def _minkowski_distance(self, x1, x2):
        return np.sum(np.abs(x1 - x2) ** self.p) ** (1 / self.p)
    
    def fit(self, X, y):
        unique_labels = np.unique(y)
        self.label_to_int = {label: idx for idx, label in enumerate(unique_labels)}
        self.int_to_label = {idx: label for label, idx in self.label_to_int.items()}
        y_int = np.array([self.label_to_int[label] for label in y])
        self.X_train = X
        self.y_train = y_int
    
    def predict(self, X):
        y_pred_int = [self._predict(x) for x in X]
        y_pred = [self.int_to_label[y_int] for y_int in y_pred_int]
        return np.array(y_pred)
    
    def _predict(self, x):
        # Compute distances based on the metric
        if self.distance_metric == "euclidean":
            distances = [self._euclidean_distance(x, x_train) for x_train in self.X_train]
        elif self.distance_metric == "manhattan":
            distances = [self._manhattan_distance(x, x_train) for x_train in self.X_train]
        elif self.distance_metric == "cosine":
            distances = [self._cosine_distance(x, x_train) for x_train in self.X_train]
        elif self.distance_metric == "hamming":
            distances = [self._hamming_distance(x, x_train) for x_train in self.X_train]
        elif self.distance_metric == "minkowski":
            distances = [self._minkowski_distance(x, x_train) for x_train in self.X_train]
        else:
            raise ValueError("Invalid distance metric.")
        
        # Get the indices of the k smallest distances
        k_indices = np.argsort(distances)[:self.k]
        k_nearest_labels = [self.y_train[i] for i in k_indices]
        
        # Majority vote
        most_common = np.bincount(k_nearest_labels).argmax()
        return most_common
    
    def evaluate(self, X, y):
        y_pred = self.predict(X) #Returning predict (Subtask 2)
        f1 = f1_score(y, y_pred, average='macro')
        accuracy = accuracy_score(y, y_pred)
        precision = precision_score(y, y_pred, average='macro')
        recall = recall_score(y, y_pred, average='macro')
        
        return {"f1_score": f1, "accuracy": accuracy, "precision": precision, "recall": recall}

    def train_val_evaluate(self, X_train, y_train, X_val, y_val):
        self.fit(X_train, y_train)
        return self.evaluate(X_val, y_val)

# Load the data
data = np.load('data.npy', allow_pickle=True)

# Extract features and labels from the first 1500 rows
X_resnet = data[:1500, 1]
X_vit = data[:1500, 2]
y = data[:1500, 3]

# Convert 1D arrays of 2D arrays into proper 2D arrays
X_resnet_2D = np.vstack(X_resnet).reshape(-1, 1024)
X_vit_2D = np.vstack(X_vit).reshape(-1, 512)

# Concatenate along the second axis to create a single feature vector
X_combined = np.hstack([X_resnet_2D, X_vit_2D])

# Perform a single train-validation split
X_train_combined, X_val_combined, y_train, y_val = train_test_split(X_combined, y, test_size=0.2, random_state=42)

# Deconvolute the combined features back into ResNet and ViT features for individual use, if needed
X_train_resnet = X_train_combined[:, :1024]
X_train_vit = X_train_combined[:, 1024:]

X_val_resnet = X_val_combined[:, :1024]
X_val_vit = X_val_combined[:, 1024:]

# Initialize the KNN class
knn_instance = KNN(k=3, encoder_type='resnet', distance_metric='euclidean')

# Train and evaluate
evaluation_results = knn_instance.train_val_evaluate(X_train_combined, y_train, X_val_combined, y_val)
print("Evaluation Results:", evaluation_results)

# Initialize the KNN class
knn_instance = KNN(k=3, encoder_type='vit', distance_metric='euclidean')

# Train and evaluate
evaluation_results = knn_instance.train_val_evaluate(X_train_combined, y_train, X_val_combined, y_val)
print("Evaluation Results:", evaluation_results)
# Out:
# /usr/lib/python3/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/lib/python3/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Evaluation Results: {'f1_score': 0.1203463611551847, 'accuracy': 0.22333333333333333, 'precision': 0.12583111333111333, 'recall': 0.15112942612942612}
# Evaluation Results: {'f1_score': 0.1203463611551847, 'accuracy': 0.22333333333333333, 'precision': 0.12583111333111333, 'recall': 0.15112942612942612}
# /usr/lib/python3/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/lib/python3/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
print("Shape of X_resnet:", np.shape(X_resnet))
print("Shape of X_vit:", np.shape(X_vit))

#For checking if resnet and vit have same shape or not
# Out:
# Shape of X_resnet: (1500,)
# Shape of X_vit: (1500,)

# %% [markdown]
# Hyperparameter tuning is the process of systematically searching for the best combination of hyperparameters that optimizes a model's performance for a particular task.
#
# In machine learning, a model's configuration is determined by both its parameters and its hyperparameters. Here's the distinction between the two:
#
# Parameters: These are the parts of the model that are learned from the training data. For instance, in a linear regression model, the coefficients are parameters. In a neural network, the weights and biases are parameters.
#
# Hyperparameters: These are the settings or knobs you can tweak before training a model. They are not learned from the data but rather are set beforehand. Examples include the learning rate in many optimization algorithms, the depth of a decision tree, the number of hidden layers in a neural network, or the
#
# k in K-Nearest Neighbors.
# Hyperparameter tuning aims to find the hyperparameters that yield the best performance, as measured on a validation set. This can be done in several ways:
#
# 1. Grid Search: This involves exhaustively testing a predefined set of hyperparameters. For instance, for KNN, you might try k values of 1, 2, 3, ..., 10 and measure performance for each.
#
# 2. Random Search: Instead of trying every possible combination, random combinations of hyperparameters are tried. This can be faster and, surprisingly, often finds better or equivalent hyperparameters compared to grid search.
#
# 3. Bayesian Optimization: This is a more sophisticated method that builds a probabilistic model of the function mapping from hyperparameters to a validation score, and chooses new hyperparameters to try based on this model.
#
# 4. Gradient-based optimization: This method computes gradients with respect to hyperparameters and moves in the direction that improves them. This is mainly used for neural networks.
#
# 5. Evolutionary Algorithms: These algorithms mimic the process of natural selection to search for better hyperparameters.
#
# Hyperparameter tuning can be computationally expensive because each set of hyperparameters requires training a new model. Thus, techniques like early stopping (for iterative algorithms like gradient descent) can be very beneficial.
#
# In the context of your KNN implementation, hyperparameters could include:
#
# The number of neighbors (
#
# k).
# The type of distance metric (Euclidean, Manhattan, Cosine, etc.).
# The encoder type (ResNet, ViT, etc.).
# Any weighting schemes for neighbors.
# It's essential to remember that hyperparameter tuning should be done using a separate validation set or cross-validation to avoid overfitting to the training data. Once the best hyperparameters are found, the final model performance should be tested on a separate test set.

# %%
#Below is the implementation of 2.4.1

import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import f1_score, accuracy_score, precision_score, recall_score
from sklearn.model_selection import train_test_split
from collections import Counter

# KNN Class Definition
class KNN:
    def __init__(self, k=3, encoder_type="resnet", distance_metric="euclidean"):
        self.k = k
        self.encoder_type = encoder_type
        self.distance_metric = distance_metric
        self.X_train = None
        self.y_train = None
        self.label_to_int = {}
        self.int_to_label = {}

#Define the distances

    def _euclidean_distance(self, x1, x2):
        return np.sqrt(np.sum((x1 - x2) ** 2))
    
    def _manhattan_distance(self, x1, x2):
        return np.sum(np.abs(x1 - x2))
    
    def _cosine_distance(self, x1, x2):
        dot_product = np.dot(x1, x2)
        norm_x1 = np.linalg.norm(x1)
        norm_x2 = np.linalg.norm(x2)
        return 1 - (dot_product / (norm_x1 * norm_x2))
    
    def _hamming_distance(self, x1, x2):
        return np.sum(x1 != x2)
    
    def _minkowski_distance(self, x1, x2, p=3):
        return np.sum(np.abs(x1 - x2) ** p) ** (1 / p)
    
    def fit(self, X, y):
        unique_labels = np.unique(y)
        self.label_to_int = {label: idx for idx, label in enumerate(unique_labels)}
        self.int_to_label = {idx: label for label, idx in self.label_to_int.items()}
        y_int = np.array([self.label_to_int[label] for label in y])
        self.X_train = X
        self.y_train = y_int
    
    def predict(self, X):
        y_pred_int = [self._predict(x) for x in X]
        y_pred = [self.int_to_label[y_int] for y_int in y_pred_int]
        return np.array(y_pred)
    
    def _predict(self, x):
        if self.distance_metric == "euclidean":
            distances = [self._euclidean_distance(x, x_train) for x_train in self.X_train]
        elif self.distance_metric == "manhattan":
            distances = [self._manhattan_distance(x, x_train) for x_train in self.X_train]
        elif self.distance_metric == "cosine":
            distances = [self._cosine_distance(x, x_train) for x_train in self.X_train]
        elif self.distance_metric == "hamming":
            distances = [self._hamming_distance(x, x_train) for x_train in self.X_train]
        elif self.distance_metric == "minkowski":
            distances = [self._minkowski_distance(x, x_train) for x_train in self.X_train]
        else:
            raise ValueError("Invalid distance metric.")
        
        k_indices = np.argsort(distances)[:self.k]
        k_nearest_labels = [self.y_train[i] for i in k_indices]
        
        most_common = np.bincount(k_nearest_labels).argmax()
        return most_common
    
    

    def train_val_evaluate(self, X_train, y_train, X_val, y_val):
        self.fit(X_train, y_train)
        return self.evaluate(X_val, y_val)


    def evaluate(self, X, y):
        y_pred = self.predict(X)
        f1 = f1_score(y, y_pred, average='macro', zero_division=1)
        accuracy = accuracy_score(y, y_pred)
        precision = precision_score(y, y_pred, average='macro', zero_division=1)
        recall = recall_score(y, y_pred, average='macro', zero_division=1)
        
        return {"f1_score": f1, "accuracy": accuracy, "precision": precision, "recall": recall}

# Load the data and preprocess as done previously
data = np.load('data.npy', allow_pickle=True)
X_resnet = data[:1500, 1]
X_vit = data[:1500, 2]
y = data[:1500, 3]

X_resnet_2D = np.vstack(X_resnet).reshape(-1, 1024)
X_vit_2D = np.vstack(X_vit).reshape(-1, 512)
X_combined = np.hstack([X_resnet_2D, X_vit_2D])

# Count the occurrences of each class in y
class_counts = Counter(y)

# Find classes with only one sample
single_sample_classes = [cls for cls, count in class_counts.items() if count < 2]

# Remove samples of those classes from X and y
mask = np.isin(y, single_sample_classes, invert=True)
X_combined_filtered = X_combined[mask]
y_filtered = y[mask]

# Using stratified sampling to ensure all classes are represented in both training and test sets
X_train_combined, X_val_combined, y_train, y_val = train_test_split(X_combined_filtered, y_filtered, test_size=0.2, random_state=42, stratify=y_filtered)

# Hyperparameter tuning
k_values = list(range(1, 41))  # considering k values from 1 to 41
distance_metrics = ["euclidean", "manhattan", "cosine", "hamming", "minkowski"]
encoders = ["resnet", "vit"]

results = []

for k in k_values:
    for distance in distance_metrics:
        for encoder in encoders:
            knn = KNN(k=k, encoder_type=encoder, distance_metric=distance)
            evaluation = knn.train_val_evaluate(X_train_combined, y_train, X_val_combined, y_val)
            accuracy = evaluation['accuracy']
            results.append((accuracy, k, encoder, distance))

# Sort the results based on accuracy
sorted_results = sorted(results, key=lambda x: x[0], reverse=True)

# Print top 20 combinations
print("Top 20 (k, encoder, distance metric) combinations based on validation accuracy:")
for idx, (accuracy, k, encoder, distance) in enumerate(sorted_results[:20]):
    print(f"{idx + 1}. Accuracy: {accuracy:.4f}, k: {k}, Encoder: {encoder}, Distance: {distance}")

# Plot k vs accuracy for a specific distance metric and encoder choice
chosen_distance = "euclidean"
chosen_encoder = "resnet"

k_values_plot = []
accuracies_plot = []

for accuracy, k, encoder, distance in sorted_results:
    if encoder == chosen_encoder and distance == chosen_distance:
        k_values_plot.append(k)
        accuracies_plot.append(accuracy)

plt.plot(k_values_plot, accuracies_plot, marker='o')
plt.xlabel('k')
plt.ylabel('Validation Accuracy')
plt.title(f'k vs Validation Accuracy for {chosen_encoder} encoder and {chosen_distance} distance')
plt.grid(True)
plt.show()
# Out:
# Top 20 (k, encoder, distance metric) combinations based on validation accuracy:
# 1. Accuracy: 0.3077, k: 1, Encoder: resnet, Distance: manhattan
# 2. Accuracy: 0.3077, k: 1, Encoder: vit, Distance: manhattan
# 3. Accuracy: 0.3043, k: 1, Encoder: resnet, Distance: euclidean
# 4. Accuracy: 0.3043, k: 1, Encoder: vit, Distance: euclidean
# 5. Accuracy: 0.3010, k: 9, Encoder: resnet, Distance: manhattan
# 6. Accuracy: 0.3010, k: 9, Encoder: vit, Distance: manhattan
# 7. Accuracy: 0.3010, k: 10, Encoder: resnet, Distance: manhattan
# 8. Accuracy: 0.3010, k: 10, Encoder: vit, Distance: manhattan
# 9. Accuracy: 0.2977, k: 1, Encoder: resnet, Distance: cosine
# 10. Accuracy: 0.2977, k: 1, Encoder: vit, Distance: cosine
# 11. Accuracy: 0.2977, k: 1, Encoder: resnet, Distance: minkowski
# 12. Accuracy: 0.2977, k: 1, Encoder: vit, Distance: minkowski
# 13. Accuracy: 0.2977, k: 8, Encoder: resnet, Distance: manhattan
# 14. Accuracy: 0.2977, k: 8, Encoder: vit, Distance: manhattan
# 15. Accuracy: 0.2943, k: 6, Encoder: resnet, Distance: euclidean
# 16. Accuracy: 0.2943, k: 6, Encoder: vit, Distance: euclidean
# 17. Accuracy: 0.2943, k: 6, Encoder: resnet, Distance: manhattan
# 18. Accuracy: 0.2943, k: 6, Encoder: vit, Distance: manhattan
# 19. Accuracy: 0.2943, k: 11, Encoder: resnet, Distance: manhattan
# 20. Accuracy: 0.2943, k: 11, Encoder: vit, Distance: manhattan

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import f1_score, accuracy_score, precision_score, recall_score
from sklearn.model_selection import train_test_split


# KNN Class Definition
class KNN:
    def __init__(self, k=3, encoder_type="resnet", distance_metric="euclidean"):
        self.k = k
        self.encoder_type = encoder_type
        self.distance_metric = distance_metric
        self.X_train = None
        self.y_train = None
        self.label_to_int = {}
        self.int_to_label = {}

    def _euclidean_distance(self, x1, x2):
        return np.sqrt(np.sum((x1 - x2) ** 2))
    
    def _manhattan_distance(self, x1, x2):
        return np.sum(np.abs(x1 - x2))
    
    def _cosine_distance(self, x1, x2):
        dot_product = np.dot(x1, x2)
        norm_x1 = np.linalg.norm(x1)
        norm_x2 = np.linalg.norm(x2)
        return 1 - (dot_product / (norm_x1 * norm_x2))
    
    def _hamming_distance(self, x1, x2):
        return np.sum(x1 != x2)
    
    def _minkowski_distance(self, x1, x2, p=3):
        return np.sum(np.abs(x1 - x2) ** p) ** (1 / p)
    
    def fit(self, X, y):
        unique_labels = np.unique(y)
        self.label_to_int = {label: idx for idx, label in enumerate(unique_labels)}
        self.int_to_label = {idx: label for label, idx in self.label_to_int.items()}
        y_int = np.array([self.label_to_int[label] for label in y])
        self.X_train = X
        self.y_train = y_int
    
    def predict(self, X):
        y_pred_int = [self._predict(x) for x in X]
        y_pred = [self.int_to_label[y_int] for y_int in y_pred_int]
        return np.array(y_pred)
    
    def _predict(self, x):
        if self.distance_metric == "euclidean":
            distances = [self._euclidean_distance(x, x_train) for x_train in self.X_train]
        elif self.distance_metric == "manhattan":
            distances = [self._manhattan_distance(x, x_train) for x_train in self.X_train]
        elif self.distance_metric == "cosine":
            distances = [self._cosine_distance(x, x_train) for x_train in self.X_train]
        elif self.distance_metric == "hamming":
            distances = [self._hamming_distance(x, x_train) for x_train in self.X_train]
        elif self.distance_metric == "minkowski":
            distances = [self._minkowski_distance(x, x_train) for x_train in self.X_train]
        else:
            raise ValueError("Invalid distance metric.")
        
        k_indices = np.argsort(distances)[:self.k]
        k_nearest_labels = [self.y_train[i] for i in k_indices]
        
        most_common = np.bincount(k_nearest_labels).argmax()
        return most_common
    
    

    def train_val_evaluate(self, X_train, y_train, X_val, y_val):
        self.fit(X_train, y_train)
        return self.evaluate(X_val, y_val)


    def evaluate(self, X, y):
        y_pred = self.predict(X)
        f1 = f1_score(y, y_pred, average='macro', zero_division=1)
        accuracy = accuracy_score(y, y_pred)
        precision = precision_score(y, y_pred, average='macro', zero_division=1)
        recall = recall_score(y, y_pred, average='macro', zero_division=1)
        
        return {"f1_score": f1, "accuracy": accuracy, "precision": precision, "recall": recall}

# Load the data and preprocess as done previously
data = np.load('data.npy', allow_pickle=True)
X_resnet = data[:1500, 1]
X_vit = data[:1500, 2]
y = data[:1500, 3]

X_resnet_2D = np.vstack(X_resnet).reshape(-1, 1024)
X_vit_2D = np.vstack(X_vit).reshape(-1, 512)
X_combined = np.hstack([X_resnet_2D, X_vit_2D])

# Count the occurrences of each class in y
class_counts = Counter(y)

# Find classes with only one sample
single_sample_classes = [cls for cls, count in class_counts.items() if count < 2]

# Remove samples of those classes from X and y
mask = np.isin(y, single_sample_classes, invert=True)
X_combined_filtered = X_combined[mask]
y_filtered = y[mask]

# Using stratified sampling to ensure all classes are represented in both training and test sets
X_train_combined, X_val_combined, y_train, y_val = train_test_split(X_combined_filtered, y_filtered, test_size=0.2, random_state=42, stratify=y_filtered)

# # Hyperparameter tuning
# k_values = list(range(1, 41))  # considering k values from 1 to 41
# distance_metrics = ["euclidean", "manhattan", "cosine", "hamming", "minkowski"]
# encoders = ["resnet", "vit"]

# results = []

# for k in k_values:
#     for distance in distance_metrics:
#         for encoder in encoders:
#             knn = KNN(k=k, encoder_type=encoder, distance_metric=distance)
#             evaluation = knn.train_val_evaluate(X_train_combined, y_train, X_val_combined, y_val)
#             accuracy = evaluation['accuracy']
#             results.append((accuracy, k, encoder, distance))

# # Sort the results based on accuracy
# sorted_results = sorted(results, key=lambda x: x[0], reverse=True)

# # Print top 20 combinations
# print("Top 20 (k, encoder, distance metric) combinations based on validation accuracy:")
# for idx, (accuracy, k, encoder, distance) in enumerate(sorted_results[:20]):
#     print(f"{idx + 1}. Accuracy: {accuracy:.4f}, k: {k}, Encoder: {encoder}, Distance: {distance}")

# # Plot k vs accuracy for a specific distance metric and encoder choice
# chosen_distance = "euclidean"
# chosen_encoder = "resnet"

# k_values_plot = []
# accuracies_plot = []

# for accuracy, k, encoder, distance in sorted_results:
#     if encoder == chosen_encoder and distance == chosen_distance:
#         k_values_plot.append(k)
#         accuracies_plot.append(accuracy)

# plt.plot(k_values_plot, accuracies_plot, marker='o')
# plt.xlabel('k')
# plt.ylabel('Validation Accuracy')
# plt.title(f'k vs Validation Accuracy for {chosen_encoder} encoder and {chosen_distance} distance')
# plt.grid(True)
# plt.show()

k_values = list(range(1, 41))  # considering k values up to 40, as you pointed out
distance_metrics = ["euclidean", "manhattan", "cosine", "hamming", "minkowski"]
encoders = ["resnet", "vit"]

results = []

for k in k_values:
    for distance in distance_metrics:
        for encoder in encoders:
            knn = KNN(k=k, encoder_type=encoder, distance_metric=distance)
            evaluation = knn.train_val_evaluate(X_train_combined, y_train, X_val_combined, y_val)
            accuracy = evaluation['accuracy']
            results.append((accuracy, k, encoder, distance))

# Sort the results based on accuracy
sorted_results = sorted(results, key=lambda x: x[0], reverse=True)

# Print top 20 combinations
print("Top 20 (k, encoder, distance metric) combinations based on validation accuracy:")
for idx, (accuracy, k, encoder, distance) in enumerate(sorted_results[:20]):
    print(f"{idx + 1}. Accuracy: {accuracy:.4f}, k: {k}, Encoder: {encoder}, Distance: {distance}")

# Plot k vs accuracy for each distance metric and encoder choice
for distance in distance_metrics:
    for encoder in encoders:
        k_values_plot = []
        accuracies_plot = []
        for accuracy, k, enc, dist in sorted_results:
            if enc == encoder and dist == distance:
                k_values_plot.append(k)
                accuracies_plot.append(accuracy)
        
        plt.figure()
        plt.plot(k_values_plot, accuracies_plot, marker='o')
        plt.xlabel('k')
        plt.ylabel('Validation Accuracy')
        plt.title(f'k vs Validation Accuracy for {encoder} encoder and {distance} distance')
        plt.grid(True)
        plt.show()
# Out:
# Top 20 (k, encoder, distance metric) combinations based on validation accuracy:
# 1. Accuracy: 0.3077, k: 1, Encoder: resnet, Distance: manhattan
# 2. Accuracy: 0.3077, k: 1, Encoder: vit, Distance: manhattan
# 3. Accuracy: 0.3043, k: 1, Encoder: resnet, Distance: euclidean
# 4. Accuracy: 0.3043, k: 1, Encoder: vit, Distance: euclidean
# 5. Accuracy: 0.3010, k: 9, Encoder: resnet, Distance: manhattan
# 6. Accuracy: 0.3010, k: 9, Encoder: vit, Distance: manhattan
# 7. Accuracy: 0.3010, k: 10, Encoder: resnet, Distance: manhattan
# 8. Accuracy: 0.3010, k: 10, Encoder: vit, Distance: manhattan
# 9. Accuracy: 0.2977, k: 1, Encoder: resnet, Distance: cosine
# 10. Accuracy: 0.2977, k: 1, Encoder: vit, Distance: cosine
# 11. Accuracy: 0.2977, k: 1, Encoder: resnet, Distance: minkowski
# 12. Accuracy: 0.2977, k: 1, Encoder: vit, Distance: minkowski
# 13. Accuracy: 0.2977, k: 8, Encoder: resnet, Distance: manhattan
# 14. Accuracy: 0.2977, k: 8, Encoder: vit, Distance: manhattan
# 15. Accuracy: 0.2943, k: 6, Encoder: resnet, Distance: euclidean
# 16. Accuracy: 0.2943, k: 6, Encoder: vit, Distance: euclidean
# 17. Accuracy: 0.2943, k: 6, Encoder: resnet, Distance: manhattan
# 18. Accuracy: 0.2943, k: 6, Encoder: vit, Distance: manhattan
# 19. Accuracy: 0.2943, k: 11, Encoder: resnet, Distance: manhattan
# 20. Accuracy: 0.2943, k: 11, Encoder: vit, Distance: manhattan

# %% [markdown]
# The below markdowns are with respect to Task 2.6.1:

# %% [markdown]
# The expected output [Verified with chatgpt and it's responses given below]:
#
# 1. Linear Increase in Time: The inference time generally increases as the number of samples in the training set increases. This is consistent with the O(N) time complexity of the KNN algorithm for inference.
#
# 2. Scikit-learn Efficiency: The Scikit-learn KNN implementation is generally more efficient than custom implementations, which is what your graph shows.
#
# 3. Optimized vs Best vs Initial: Your graph also suggests that your optimized and best models perform similarly, and both are better than the initial model. This could indicate that your optimization efforts had some impact, albeit not a large one, or that your best and optimized models are essentially the same in terms of computational efficiency.

# %% [markdown]
# ANALYSIS OF THE BELOW OUTPUT:
#
# 1. Inference Time for Different KNN Models:
#
# -> The graph shows the inference time of various KNN models.
# -> The Scikit-learn KNN model has the shortest inference time, indicating it's the most efficient among the four.
# -> The initial, best, and optimized models (custom implementations) have more extended inference times, with the "best" and "optimized" versions having nearly the same performance.
#
# 2. Inference Time vs. Training Data Size:
#
# -> The graph shows how the inference time changes with varying training data sizes.
# -> All models exhibit an increase in inference time as the training size increases, which is expected since KNN has to compute distances with more data points.
# -> Again, the Scikit-learn KNN model performs the best, maintaining a relatively low inference time across all training sizes.
# -> The initial, best, and optimized KNN models (custom implementations) have similar trends, but their inference times are notably higher.

# %%
#Below is the implementation of 2.6.1 (Vectorized approach)

import numpy as np
import time
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import f1_score, accuracy_score, precision_score, recall_score

# Load your data here
data = np.load('data.npy', allow_pickle=True)
X_resnet = data[:, 1]
X_vit = data[:, 2]
y = data[:, 3]
X_resnet_2D = np.vstack(X_resnet).reshape(-1, 1024)
X_vit_2D = np.vstack(X_vit).reshape(-1, 512)
X_combined = np.hstack([X_resnet_2D, X_vit_2D])

# Split the data into training and test sets
X_train_combined, X_test_combined, y_train, y_test = train_test_split(X_combined, y, test_size=0.2, random_state=42)

class KNN:
    def __init__(self, k=3, encoder_type="resnet", distance_metric="euclidean"):
        self.k = k
        self.encoder_type = encoder_type
        self.distance_metric = distance_metric
        self.X_train = None
        self.y_train = None
        self.label_to_int = {}
        self.int_to_label = {}

    def fit(self, X, y):
        unique_labels = np.unique(y)
        self.label_to_int = {label: idx for idx, label in enumerate(unique_labels)}
        self.int_to_label = {idx: label for label, idx in self.label_to_int.items()}
        y_int = np.array([self.label_to_int[label] for label in y])
        self.X_train = X
        self.y_train = y_int

    def predict(self, X):
        y_pred_int = [self._predict(x) for x in X]
        y_pred = [self.int_to_label[y_int] for y_int in y_pred_int]
        return np.array(y_pred)

    def _predict(self, x):
        if self.distance_metric == "euclidean":
            distances = np.sqrt(np.sum((self.X_train - x)**2, axis=1))
        elif self.distance_metric == "manhattan":
            distances = np.sum(np.abs(self.X_train - x), axis=1)
        elif self.distance_metric == "cosine":
            dot_product = np.dot(self.X_train, x)
            norm_x = np.linalg.norm(x)
            norm_X_train = np.linalg.norm(self.X_train, axis=1)
            distances = 1 - (dot_product / (norm_x * norm_X_train))
        elif self.distance_metric == "hamming":
            distances = np.sum(self.X_train != x, axis=1)
        elif self.distance_metric == "minkowski":
            p = 3  # You can make 'p' a parameter if you like
            distances = np.sum(np.abs(self.X_train - x)**p, axis=1)**(1/p)
        else:
            raise ValueError("Invalid distance metric.")

        k_indices = np.argsort(distances)[:self.k]
        k_nearest_labels = [self.y_train[i] for i in k_indices]

        most_common = np.bincount(k_nearest_labels).argmax()
        return most_common

    def evaluate(self, X, y):
        y_pred = self.predict(X)
        f1 = f1_score(y, y_pred, average='macro', zero_division=1)
        accuracy = accuracy_score(y, y_pred)
        precision = precision_score(y, y_pred, average='macro', zero_division=1)
        recall = recall_score(y, y_pred, average='macro', zero_division=1)

        return {"f1_score": f1, "accuracy": accuracy, "precision": precision, "recall": recall}

# Initialize models
initial_knn = KNN(k=3)
best_knn = KNN(k=10)  
optimized_knn = KNN(k=10)  
sklearn_knn = KNeighborsClassifier(n_neighbors=10)

# Time measurement function
def measure_time(model, X_test):
    start_time = time.time()
    predictions = model.predict(X_test)
    return time.time() - start_time

# Initialize variables for plotting
train_sizes = np.linspace(0.1, 1.0, 10)
times_initial = []
times_best = []
times_optimized = []
times_sklearn = []

# Measure inference time vs training data size
for size in train_sizes:
    if size == 1.0:
        X_train, y_train_subset = X_train_combined, y_train
    else:
        X_train, _, y_train_subset, _ = train_test_split(X_train_combined, y_train, train_size=size, random_state=42)

    initial_knn.fit(X_train, y_train_subset)
    best_knn.fit(X_train, y_train_subset)
    optimized_knn.fit(X_train, y_train_subset)
    sklearn_knn.fit(X_train, y_train_subset)

    times_initial.append(measure_time(initial_knn, X_test_combined))
    times_best.append(measure_time(best_knn, X_test_combined))
    times_optimized.append(measure_time(optimized_knn, X_test_combined))
    times_sklearn.append(measure_time(sklearn_knn, X_test_combined))

# Plotting inference time vs training data size
plt.figure(figsize=(10, 6))
plt.plot(train_sizes, times_initial, label='Initial KNN')
plt.plot(train_sizes, times_best, label='Best KNN')
plt.plot(train_sizes, times_optimized, label='Optimized KNN')
plt.plot(train_sizes, times_sklearn, label='Scikit-learn KNN')
plt.xlabel('Training Data Size')
plt.ylabel('Time (seconds)')
plt.title('Inference Time vs Training Data Size')
plt.legend()
plt.show()

# Measure inference time for each model
initial_knn.fit(X_train_combined, y_train)
best_knn.fit(X_train_combined, y_train)
optimized_knn.fit(X_train_combined, y_train)
sklearn_knn.fit(X_train_combined, y_train)

time_initial = measure_time(initial_knn, X_test_combined)
time_best = measure_time(best_knn, X_test_combined)
time_optimized = measure_time(optimized_knn, X_test_combined)
time_sklearn = measure_time(sklearn_knn, X_test_combined)

# Plotting inference time for initial KNN model, best KNN model, most optimized KNN model, and the default sklearn KNN model.
labels = ['Initial KNN', 'Best KNN', 'Optimized KNN', 'Scikit-learn KNN']
times = [time_initial, time_best, time_optimized, time_sklearn]

plt.figure(figsize=(10, 6))


plt.figure(figsize=(10, 6))
plt.barh(labels, times, color='dodgerblue')
plt.xlabel('Time (seconds)')
plt.ylabel('Model')
plt.title('Inference Time for Different KNN Models')
plt.gca().invert_yaxis()  # This is to have the Initial KNN at the top and Scikit-learn KNN at the bottom
plt.show()

# %% [markdown]
# PART 2 - DECISION TREES

# %%
# Import necessary libraries
import pandas as pd

# Load the data
try:
    data_dt = pd.read_csv('/home/aishani/Documents/GitHub/SMAI-Assignment-1/SMAI ASSIGNMENT 1/advertisement.csv')
    print("Data loaded successfully.")
except Exception as e:
    print(f"An error occurred while loading the data: {e}")

# Display basic statistics
print("Basic Statistics:")
print(data_dt.describe())

# Display first few rows
print("First few rows:")
print(data_dt.head())
# Out:
# Data loaded successfully.
# Basic Statistics:
#                age        income     children  purchase_amount
# count  1000.000000   1000.000000  1000.000000      1000.000000
# mean     40.836000  49349.796167     1.508000       101.098170
# std      13.786848   9894.479148     1.129253        20.348736
# min      18.000000  21908.867759     0.000000        23.482179
# 25%      28.000000  42577.352034     0.000000        87.699577
# 50%      41.000000  48993.757137     1.000000       101.587560
# 75%      53.000000  56566.795992     3.000000       114.718926
# max      64.000000  79459.294416     3.000000       168.978628
# First few rows:
#    age  gender        income    education  married  children           city  \
# 0   45    Male  61271.953359       Master    False         3    Lake Sheila
# 1   24  Female  53229.101074  High School    False         1   Crystalburgh
# 2   45  Female  30066.046684     Bachelor     True         3  Margaretburgh
# 3   19    Male  48950.246384          PhD    False         0  Williamshaven
# 4   29  Female  44792.627094       Master    False         0       New Paul
#
#     occupation  purchase_amount most bought item  \
# 0       Doctor        87.697118          monitor
# 1  Businessman       115.135586         lipstick
# 2     Engineer       101.694559         biscuits
# 3       Lawyer        97.964887            maggi
# 4  Businessman        86.847281           carpet
#
#                              labels
# 0       electronics clothing sports
# 1                  furniture beauty
# 2  clothing electronics food sports
# 3                              food
# 4                              home

# %%
# Explore the 'labels' column
labels_col = data_dt['labels'].str.split(', ')

# Count the number of unique labels
unique_labels = set(x for sublist in labels_col for x in sublist)
print(f"Total number of unique labels: {len(unique_labels)}")

# Distribution of number of labels per instance
label_count_per_instance = labels_col.apply(len)
print("Distribution of number of labels per instance:")
print(label_count_per_instance.value_counts().sort_index())

# Count the number of unique label combinations
unique_label_combinations = set(tuple(sorted(x)) for x in labels_col)
print(f"Total number of unique label combinations: {len(unique_label_combinations)}")
# Out:
# Total number of unique labels: 397
# Distribution of number of labels per instance:
# labels
# 1    1000
# Name: count, dtype: int64
# Total number of unique label combinations: 397

# %%
import csv
 
# opening the CSV file
with open('/home/aishani/Documents/GitHub/SMAI-Assignment-1/SMAI ASSIGNMENT 1/advertisement.csv', mode ='r') as file: 
       
       # reading the CSV file
       data_dt = csv.DictReader(file)      
       
       # displaying the contents of the CSV file
       for lines in data_dt:
            print(lines)
# Out:
# {'age': '45', 'gender': 'Male', 'income': '61271.953358890096', 'education': 'Master', 'married': 'False', 'children': '3', 'city': 'Lake Sheila', 'occupation': 'Doctor', 'purchase_amount': '87.69711834242366', 'most bought item': 'monitor', 'labels': 'electronics clothing sports'}
# {'age': '24', 'gender': 'Female', 'income': '53229.101073561775', 'education': 'High School', 'married': 'False', 'children': '1', 'city': 'Crystalburgh', 'occupation': 'Businessman', 'purchase_amount': '115.13558622549097', 'most bought item': 'lipstick', 'labels': 'furniture beauty'}
# {'age': '45', 'gender': 'Female', 'income': '30066.04668359846', 'education': 'Bachelor', 'married': 'True', 'children': '3', 'city': 'Margaretburgh', 'occupation': 'Engineer', 'purchase_amount': '101.69455857438265', 'most bought item': 'biscuits', 'labels': 'clothing electronics food sports'}
# {'age': '19', 'gender': 'Male', 'income': '48950.246384098704', 'education': 'PhD', 'married': 'False', 'children': '0', 'city': 'Williamshaven', 'occupation': 'Lawyer', 'purchase_amount': '97.9648871394473', 'most bought item': 'maggi', 'labels': 'food'}
# {'age': '29', 'gender': 'Female', 'income': '44792.62709365476', 'education': 'Master', 'married': 'False', 'children': '0', 'city': 'New Paul', 'occupation': 'Businessman', 'purchase_amount': '86.84728090385065', 'most bought item': 'carpet', 'labels': 'home'}
# {'age': '20', 'gender': 'Female', 'income': '51266.76704661121', 'education': 'Master', 'married': 'True', 'children': '3', 'city': 'Frankport', 'occupation': 'Scientist', 'purchase_amount': '95.14510322277383', 'most bought item': 'laptop', 'labels': 'sports electronics books'}
# {'age': '27', 'gender': 'Male', 'income': '29578.136416224603', 'education': 'Bachelor', 'married': 'True', 'children': '3', 'city': 'North Shelbyshire', 'occupation': 'Lawyer', 'purchase_amount': '69.02284162170585', 'most bought item': 'table', 'labels': 'beauty furniture clothing'}
# {'age': '20', 'gender': 'Female', 'income': '35325.309004722', 'education': 'PhD', 'married': 'False', 'children': '3', 'city': 'South Raventown', 'occupation': 'Housewife', 'purchase_amount': '110.56451724532606', 'most bought item': 'dictionary', 'labels': 'books beauty'}
# {'age': '51', 'gender': 'Male', 'income': '40232.56435567347', 'education': 'PhD', 'married': 'True', 'children': '0', 'city': 'Leonardtown', 'occupation': 'Salesman', 'purchase_amount': '107.83548978532892', 'most bought item': 'curtains', 'labels': 'electronics food home sports'}
# {'age': '19', 'gender': 'Male', 'income': '48053.58388154555', 'education': 'PhD', 'married': 'True', 'children': '0', 'city': 'South Susan', 'occupation': 'Artist', 'purchase_amount': '108.85489809675545', 'most bought item': 'chips', 'labels': 'furniture food'}
# {'age': '57', 'gender': 'Female', 'income': '60907.8446290855', 'education': 'PhD', 'married': 'True', 'children': '0', 'city': 'Gutierrezborough', 'occupation': 'HR', 'purchase_amount': '78.8316751604477', 'most bought item': 'shoes', 'labels': 'clothing home'}
# {'age': '27', 'gender': 'Female', 'income': '51033.62793525259', 'education': 'PhD', 'married': 'True', 'children': '2', 'city': 'Lake Tiffanyhaven', 'occupation': 'Scientist', 'purchase_amount': '138.6726183716063', 'most bought item': 'maggi', 'labels': 'food books'}
# {'age': '63', 'gender': 'Male', 'income': '53402.223922740784', 'education': 'High School', 'married': 'False', 'children': '0', 'city': 'New Kara', 'occupation': 'Scientist', 'purchase_amount': '118.088573489242', 'most bought item': 'curtains', 'labels': 'home'}
# {'age': '44', 'gender': 'Female', 'income': '34683.652618289125', 'education': 'Master', 'married': 'True', 'children': '2', 'city': 'West Darlenemouth', 'occupation': 'Engineer', 'purchase_amount': '89.10146519803314', 'most bought item': 'bat', 'labels': 'sports furniture food home'}
# {'age': '51', 'gender': 'Female', 'income': '48815.172160476155', 'education': 'Bachelor', 'married': 'False', 'children': '0', 'city': 'New Anthonytown', 'occupation': 'Salesman', 'purchase_amount': '65.79762232863524', 'most bought item': 'biscuits', 'labels': 'beauty clothing food'}
# {'age': '42', 'gender': 'Female', 'income': '40527.46314949081', 'education': 'High School', 'married': 'False', 'children': '2', 'city': 'Markfurt', 'occupation': 'Engineer', 'purchase_amount': '101.59731563602708', 'most bought item': 'gloves', 'labels': 'books clothing sports'}
# {'age': '39', 'gender': 'Male', 'income': '57062.63929819454', 'education': 'High School', 'married': 'False', 'children': '3', 'city': 'Scottberg', 'occupation': 'HR', 'purchase_amount': '71.08020046512671', 'most bought item': 'laptop', 'labels': 'electronics furniture food books'}
# {'age': '25', 'gender': 'Female', 'income': '40668.47895115987', 'education': 'High School', 'married': 'False', 'children': '1', 'city': 'South Tina', 'occupation': 'Businessman', 'purchase_amount': '124.48710527906474', 'most bought item': 'curtains', 'labels': 'furniture electronics home sports'}
# {'age': '47', 'gender': 'Male', 'income': '50144.63071970715', 'education': 'Bachelor', 'married': 'True', 'children': '2', 'city': 'Dawnport', 'occupation': 'Scientist', 'purchase_amount': '104.3738141829318', 'most bought item': 'biscuits', 'labels': 'clothing food beauty'}
# {'age': '47', 'gender': 'Female', 'income': '50595.565054651', 'education': 'Master', 'married': 'True', 'children': '1', 'city': 'Stevenfort', 'occupation': 'Businessman', 'purchase_amount': '112.43197735404532', 'most bought item': 'chips', 'labels': 'food furniture'}
# {'age': '36', 'gender': 'Female', 'income': '34611.512757270495', 'education': 'High School', 'married': 'True', 'children': '1', 'city': 'South Jeffreyberg', 'occupation': 'Lawyer', 'purchase_amount': '79.24646899126734', 'most bought item': 'chips', 'labels': 'home food'}
# {'age': '62', 'gender': 'Male', 'income': '51568.49387815004', 'education': 'Bachelor', 'married': 'False', 'children': '0', 'city': 'Patriciaside', 'occupation': 'Engineer', 'purchase_amount': '118.09150586231826', 'most bought item': 'pants', 'labels': 'sports clothing home'}
# {'age': '25', 'gender': 'Female', 'income': '46971.308307482876', 'education': 'Master', 'married': 'False', 'children': '1', 'city': 'South Steven', 'occupation': 'Engineer', 'purchase_amount': '109.71636831533179', 'most bought item': 'bat', 'labels': 'beauty sports'}
# {'age': '64', 'gender': 'Male', 'income': '50179.18942380713', 'education': 'High School', 'married': 'True', 'children': '3', 'city': 'Cherylstad', 'occupation': 'Businessman', 'purchase_amount': '95.4958279042497', 'most bought item': 'laptop', 'labels': 'books electronics food'}
# {'age': '23', 'gender': 'Male', 'income': '47586.43186178855', 'education': 'Master', 'married': 'True', 'children': '2', 'city': 'South Christinashire', 'occupation': 'HR', 'purchase_amount': '105.25796285592376', 'most bought item': 'novel', 'labels': 'electronics books'}
# {'age': '48', 'gender': 'Male', 'income': '57660.16177611229', 'education': 'PhD', 'married': 'True', 'children': '1', 'city': 'West Scottburgh', 'occupation': 'Scientist', 'purchase_amount': '116.65564110194168', 'most bought item': 'bed', 'labels': 'furniture food sports'}
# {'age': '57', 'gender': 'Male', 'income': '46278.466041536674', 'education': 'Master', 'married': 'False', 'children': '3', 'city': 'Grahamshire', 'occupation': 'Engineer', 'purchase_amount': '77.01256568799062', 'most bought item': 'table', 'labels': 'clothing furniture food books'}
# {'age': '50', 'gender': 'Female', 'income': '45270.63857888708', 'education': 'Master', 'married': 'False', 'children': '0', 'city': 'Tracieshire', 'occupation': 'Engineer', 'purchase_amount': '92.14969322671689', 'most bought item': 'curtains', 'labels': 'food home'}
# {'age': '25', 'gender': 'Male', 'income': '60083.70355511571', 'education': 'Bachelor', 'married': 'True', 'children': '0', 'city': 'Meadowston', 'occupation': 'Housewife', 'purchase_amount': '126.68939274445259', 'most bought item': 'lipstick', 'labels': 'home food beauty'}
# {'age': '64', 'gender': 'Male', 'income': '63176.02957964427', 'education': 'Master', 'married': 'False', 'children': '0', 'city': 'North Lindachester', 'occupation': 'Scientist', 'purchase_amount': '118.54679803586477', 'most bought item': 'mobile', 'labels': 'sports electronics furniture books'}
# {'age': '27', 'gender': 'Male', 'income': '61772.48070232014', 'education': 'PhD', 'married': 'False', 'children': '2', 'city': 'West Sarah', 'occupation': 'Lawyer', 'purchase_amount': '80.25853405593523', 'most bought item': 'cream', 'labels': 'beauty clothing home'}
# {'age': '50', 'gender': 'Female', 'income': '40800.94509740489', 'education': 'High School', 'married': 'True', 'children': '2', 'city': 'East Kristy', 'occupation': 'Unemployed', 'purchase_amount': '80.7407132964585', 'most bought item': 'encyclopedia', 'labels': 'books clothing sports beauty'}
# {'age': '31', 'gender': 'Female', 'income': '57019.16955940884', 'education': 'Bachelor', 'married': 'False', 'children': '0', 'city': 'Port Royport', 'occupation': 'Retired', 'purchase_amount': '119.80857156754274', 'most bought item': 'mobile', 'labels': 'electronics furniture food'}
# {'age': '57', 'gender': 'Female', 'income': '62617.10045992293', 'education': 'High School', 'married': 'True', 'children': '3', 'city': 'Floresfurt', 'occupation': 'Artist', 'purchase_amount': '128.026274693076', 'most bought item': 'chair', 'labels': 'furniture beauty'}
# {'age': '37', 'gender': 'Female', 'income': '58970.41784222799', 'education': 'PhD', 'married': 'False', 'children': '2', 'city': 'Timothyview', 'occupation': 'Retired', 'purchase_amount': '90.76007017165679', 'most bought item': 'shirt', 'labels': 'clothing sports books'}
# {'age': '53', 'gender': 'Female', 'income': '47683.6710820506', 'education': 'High School', 'married': 'True', 'children': '0', 'city': 'South Julie', 'occupation': 'Retired', 'purchase_amount': '71.15952750332757', 'most bought item': 'chips', 'labels': 'food electronics clothing books'}
# {'age': '41', 'gender': 'Male', 'income': '64472.841977903365', 'education': 'PhD', 'married': 'True', 'children': '2', 'city': 'Perkinshaven', 'occupation': 'Scientist', 'purchase_amount': '76.94898317887817', 'most bought item': 'gloves', 'labels': 'home sports books'}
# {'age': '19', 'gender': 'Male', 'income': '46421.930830034784', 'education': 'PhD', 'married': 'True', 'children': '2', 'city': 'Jamesberg', 'occupation': 'Businessman', 'purchase_amount': '108.92300456138298', 'most bought item': 'laptop', 'labels': 'sports electronics furniture food'}
# {'age': '28', 'gender': 'Female', 'income': '42792.335252355115', 'education': 'Bachelor', 'married': 'True', 'children': '2', 'city': 'Wesleytown', 'occupation': 'Businessman', 'purchase_amount': '93.00719862417347', 'most bought item': 'novel', 'labels': 'beauty food home books'}
# {'age': '34', 'gender': 'Female', 'income': '50458.70695248991', 'education': 'Bachelor', 'married': 'False', 'children': '1', 'city': 'Port Ralph', 'occupation': 'Businessman', 'purchase_amount': '109.91018778791812', 'most bought item': 'dictionary', 'labels': 'books clothing sports'}
# {'age': '32', 'gender': 'Male', 'income': '43808.071941851784', 'education': 'Master', 'married': 'True', 'children': '0', 'city': 'Port Ellen', 'occupation': 'Businessman', 'purchase_amount': '97.58513925005511', 'most bought item': 'laptop', 'labels': 'electronics clothing home sports'}
# {'age': '60', 'gender': 'Male', 'income': '50298.468526412944', 'education': 'Master', 'married': 'False', 'children': '0', 'city': 'South Matthewport', 'occupation': 'Housewife', 'purchase_amount': '102.74446159679812', 'most bought item': 'bed', 'labels': 'furniture clothing'}
# {'age': '36', 'gender': 'Male', 'income': '49939.40565756932', 'education': 'Master', 'married': 'False', 'children': '2', 'city': 'Melissachester', 'occupation': 'Retired', 'purchase_amount': '109.47384861127668', 'most bought item': 'shirt', 'labels': 'clothing beauty'}
# {'age': '30', 'gender': 'Female', 'income': '75087.8754300739', 'education': 'Bachelor', 'married': 'True', 'children': '0', 'city': 'East David', 'occupation': 'Salesman', 'purchase_amount': '117.5142301427671', 'most bought item': 'maggi', 'labels': 'food furniture'}
# {'age': '21', 'gender': 'Female', 'income': '55900.65834334106', 'education': 'Bachelor', 'married': 'True', 'children': '0', 'city': 'North Bradyview', 'occupation': 'Engineer', 'purchase_amount': '97.65708275942124', 'most bought item': 'sofa', 'labels': 'home electronics clothing books'}
# {'age': '22', 'gender': 'Male', 'income': '43315.95489189834', 'education': 'Bachelor', 'married': 'False', 'children': '1', 'city': 'Alicehaven', 'occupation': 'HR', 'purchase_amount': '142.1895117433039', 'most bought item': 'ball', 'labels': 'sports furniture clothing'}
# {'age': '44', 'gender': 'Female', 'income': '67543.42980101', 'education': 'PhD', 'married': 'True', 'children': '2', 'city': 'South Dawnberg', 'occupation': 'Lawyer', 'purchase_amount': '67.32506450923921', 'most bought item': 'cream', 'labels': 'beauty books'}
# {'age': '18', 'gender': 'Male', 'income': '64144.78205467261', 'education': 'Master', 'married': 'True', 'children': '1', 'city': 'Hansenburgh', 'occupation': 'Lawyer', 'purchase_amount': '100.01279800687949', 'most bought item': 'encyclopedia', 'labels': 'books'}
# {'age': '46', 'gender': 'Female', 'income': '60468.953352239616', 'education': 'Master', 'married': 'True', 'children': '2', 'city': 'Stephenfort', 'occupation': 'Unemployed', 'purchase_amount': '103.70231047958572', 'most bought item': 'monitor', 'labels': 'electronics beauty books'}
# {'age': '46', 'gender': 'Male', 'income': '61425.58928182784', 'education': 'Master', 'married': 'False', 'children': '1', 'city': 'Cynthiaberg', 'occupation': 'Artist', 'purchase_amount': '119.41931185661167', 'most bought item': 'dictionary', 'labels': 'furniture electronics books'}
# {'age': '19', 'gender': 'Male', 'income': '44284.05483724431', 'education': 'Master', 'married': 'False', 'children': '0', 'city': 'New Katelynton', 'occupation': 'Artist', 'purchase_amount': '102.88940647360394', 'most bought item': 'pants', 'labels': 'clothing food sports beauty'}
# {'age': '37', 'gender': 'Female', 'income': '46212.644202483236', 'education': 'Bachelor', 'married': 'True', 'children': '0', 'city': 'North James', 'occupation': 'Scientist', 'purchase_amount': '83.48627226674893', 'most bought item': 'maggi', 'labels': 'food home sports'}
# {'age': '58', 'gender': 'Female', 'income': '51057.8931668608', 'education': 'Bachelor', 'married': 'True', 'children': '1', 'city': 'New Elizabeth', 'occupation': 'Engineer', 'purchase_amount': '133.76108247015858', 'most bought item': 'lipstick', 'labels': 'home beauty'}
# {'age': '59', 'gender': 'Male', 'income': '50176.11986300034', 'education': 'PhD', 'married': 'False', 'children': '0', 'city': 'Joshuaborough', 'occupation': 'Businessman', 'purchase_amount': '87.23789113613594', 'most bought item': 'ball', 'labels': 'sports'}
# {'age': '54', 'gender': 'Female', 'income': '48484.66522847292', 'education': 'High School', 'married': 'False', 'children': '3', 'city': 'North Jerry', 'occupation': 'Salesman', 'purchase_amount': '77.03417974003057', 'most bought item': 'curtains', 'labels': 'beauty furniture clothing home sports'}
# {'age': '35', 'gender': 'Female', 'income': '40317.993845782315', 'education': 'High School', 'married': 'True', 'children': '0', 'city': 'Aarontown', 'occupation': 'HR', 'purchase_amount': '104.83573849753081', 'most bought item': 'novel', 'labels': 'books electronics'}
# {'age': '42', 'gender': 'Female', 'income': '58886.92958347335', 'education': 'High School', 'married': 'True', 'children': '3', 'city': 'West Daniel', 'occupation': 'Salesman', 'purchase_amount': '152.1042844097258', 'most bought item': 'shirt', 'labels': 'electronics clothing food books'}
# {'age': '25', 'gender': 'Male', 'income': '52708.950263399194', 'education': 'PhD', 'married': 'False', 'children': '3', 'city': 'Aprilmouth', 'occupation': 'HR', 'purchase_amount': '108.9685492131818', 'most bought item': 'shirt', 'labels': 'furniture electronics clothing sports'}
# {'age': '29', 'gender': 'Female', 'income': '52268.35064266082', 'education': 'High School', 'married': 'False', 'children': '3', 'city': 'Lake Amanda', 'occupation': 'HR', 'purchase_amount': '83.56369465523238', 'most bought item': 'carpet', 'labels': 'clothing home'}
# {'age': '59', 'gender': 'Female', 'income': '47076.5853663922', 'education': 'PhD', 'married': 'False', 'children': '3', 'city': 'Popehaven', 'occupation': 'Unemployed', 'purchase_amount': '127.54793571644846', 'most bought item': 'dictionary', 'labels': 'food books'}
# {'age': '33', 'gender': 'Female', 'income': '63572.50302465411', 'education': 'Master', 'married': 'True', 'children': '2', 'city': 'Donnabury', 'occupation': 'Lawyer', 'purchase_amount': '120.03972952301362', 'most bought item': 'sofa', 'labels': 'home electronics beauty'}
# {'age': '45', 'gender': 'Male', 'income': '58858.477095471506', 'education': 'Master', 'married': 'False', 'children': '0', 'city': 'East Ashleymouth', 'occupation': 'Retired', 'purchase_amount': '89.29808853926384', 'most bought item': 'maggi', 'labels': 'sports furniture clothing food home beauty books'}
# {'age': '19', 'gender': 'Female', 'income': '50332.89220106663', 'education': 'High School', 'married': 'False', 'children': '2', 'city': 'Chelseachester', 'occupation': 'Businessman', 'purchase_amount': '120.83707787970195', 'most bought item': 'ball', 'labels': 'beauty sports'}
# {'age': '24', 'gender': 'Female', 'income': '44552.09894748906', 'education': 'High School', 'married': 'False', 'children': '0', 'city': 'North Andrew', 'occupation': 'Engineer', 'purchase_amount': '121.68514597910907', 'most bought item': 'dictionary', 'labels': 'books home'}
# {'age': '44', 'gender': 'Female', 'income': '42183.725846177535', 'education': 'Master', 'married': 'False', 'children': '1', 'city': 'Hahnview', 'occupation': 'Doctor', 'purchase_amount': '80.53649282514672', 'most bought item': 'mobile', 'labels': 'electronics furniture'}
# {'age': '30', 'gender': 'Male', 'income': '54987.27776667199', 'education': 'High School', 'married': 'False', 'children': '2', 'city': 'East Anna', 'occupation': 'Salesman', 'purchase_amount': '62.24209518813997', 'most bought item': 'bed', 'labels': 'furniture food'}
# {'age': '44', 'gender': 'Male', 'income': '68786.93111812898', 'education': 'PhD', 'married': 'False', 'children': '0', 'city': 'Kingside', 'occupation': 'Salesman', 'purchase_amount': '133.8278596938748', 'most bought item': 'shoes', 'labels': 'clothing'}
# {'age': '46', 'gender': 'Female', 'income': '39312.647642314994', 'education': 'Master', 'married': 'False', 'children': '1', 'city': 'Padillaland', 'occupation': 'HR', 'purchase_amount': '112.16464960653079', 'most bought item': 'lipstick', 'labels': 'food furniture beauty'}
# {'age': '46', 'gender': 'Female', 'income': '40586.188382626206', 'education': 'Bachelor', 'married': 'False', 'children': '1', 'city': 'Martinezmouth', 'occupation': 'Doctor', 'purchase_amount': '108.01887297227418', 'most bought item': 'novel', 'labels': 'home electronics furniture beauty books'}
# {'age': '37', 'gender': 'Female', 'income': '43664.679377202105', 'education': 'PhD', 'married': 'True', 'children': '0', 'city': 'Mariemouth', 'occupation': 'Retired', 'purchase_amount': '108.95798381470098', 'most bought item': 'bat', 'labels': 'sports electronics'}
# {'age': '30', 'gender': 'Male', 'income': '51386.376828099455', 'education': 'Master', 'married': 'True', 'children': '3', 'city': 'Eugenefort', 'occupation': 'Doctor', 'purchase_amount': '86.46898786157861', 'most bought item': 'novel', 'labels': 'beauty books'}
# {'age': '49', 'gender': 'Female', 'income': '60730.37778693777', 'education': 'Master', 'married': 'True', 'children': '0', 'city': 'West Gwendolynton', 'occupation': 'Salesman', 'purchase_amount': '105.16819387916387', 'most bought item': 'bat', 'labels': 'books electronics food home sports'}
# {'age': '59', 'gender': 'Male', 'income': '43437.66527663413', 'education': 'Bachelor', 'married': 'False', 'children': '1', 'city': 'North Lisaport', 'occupation': 'Artist', 'purchase_amount': '70.93218278958771', 'most bought item': 'monitor', 'labels': 'electronics'}
# {'age': '57', 'gender': 'Female', 'income': '59157.50778260416', 'education': 'High School', 'married': 'False', 'children': '0', 'city': 'Johnsonborough', 'occupation': 'Scientist', 'purchase_amount': '119.54070902643262', 'most bought item': 'chips', 'labels': 'furniture food home'}
# {'age': '63', 'gender': 'Male', 'income': '38978.55492161637', 'education': 'Bachelor', 'married': 'True', 'children': '0', 'city': 'Rushside', 'occupation': 'Salesman', 'purchase_amount': '94.20188994818538', 'most bought item': 'lipstick', 'labels': 'clothing electronics food sports beauty'}
# {'age': '48', 'gender': 'Male', 'income': '59511.36284774721', 'education': 'PhD', 'married': 'True', 'children': '3', 'city': 'South Nicole', 'occupation': 'Lawyer', 'purchase_amount': '117.15387858365234', 'most bought item': 'table', 'labels': 'food furniture books'}
# {'age': '59', 'gender': 'Female', 'income': '27444.718353823373', 'education': 'PhD', 'married': 'False', 'children': '0', 'city': 'South Krista', 'occupation': 'Housewife', 'purchase_amount': '71.06223505534149', 'most bought item': 'dictionary', 'labels': 'home electronics furniture books'}
# {'age': '28', 'gender': 'Female', 'income': '36344.0561432044', 'education': 'Bachelor', 'married': 'False', 'children': '1', 'city': 'West Kimberlyview', 'occupation': 'Scientist', 'purchase_amount': '119.72085203956343', 'most bought item': 'gloves', 'labels': 'sports books'}
# {'age': '54', 'gender': 'Male', 'income': '39234.475401825875', 'education': 'PhD', 'married': 'True', 'children': '3', 'city': 'North Robert', 'occupation': 'HR', 'purchase_amount': '111.32002100527478', 'most bought item': 'carpet', 'labels': 'beauty home'}
# {'age': '28', 'gender': 'Male', 'income': '37749.20367053849', 'education': 'Master', 'married': 'False', 'children': '3', 'city': 'Michelleville', 'occupation': 'Housewife', 'purchase_amount': '107.20278024795503', 'most bought item': 'chair', 'labels': 'books electronics furniture beauty'}
# {'age': '26', 'gender': 'Male', 'income': '69052.16320279146', 'education': 'High School', 'married': 'True', 'children': '3', 'city': 'Dunlapside', 'occupation': 'Engineer', 'purchase_amount': '107.7798689021385', 'most bought item': 'lipstick', 'labels': 'electronics beauty'}
# {'age': '60', 'gender': 'Male', 'income': '61633.95499867969', 'education': 'High School', 'married': 'True', 'children': '3', 'city': 'Stephensside', 'occupation': 'Doctor', 'purchase_amount': '92.09842384693746', 'most bought item': 'mobile', 'labels': 'furniture electronics'}
# {'age': '57', 'gender': 'Male', 'income': '38620.059718354154', 'education': 'Bachelor', 'married': 'True', 'children': '1', 'city': 'North Jason', 'occupation': 'Retired', 'purchase_amount': '148.79277138257936', 'most bought item': 'pants', 'labels': 'clothing beauty'}
# {'age': '54', 'gender': 'Male', 'income': '38425.712975520066', 'education': 'Bachelor', 'married': 'False', 'children': '3', 'city': 'New Juanhaven', 'occupation': 'Doctor', 'purchase_amount': '69.44348085656642', 'most bought item': 'encyclopedia', 'labels': 'food books'}
# {'age': '39', 'gender': 'Female', 'income': '45885.22781553298', 'education': 'PhD', 'married': 'True', 'children': '3', 'city': 'West Amyberg', 'occupation': 'HR', 'purchase_amount': '107.9415097827092', 'most bought item': 'carpet', 'labels': 'home'}
# {'age': '39', 'gender': 'Female', 'income': '62148.03699185756', 'education': 'Bachelor', 'married': 'False', 'children': '2', 'city': 'North Sydney', 'occupation': 'Salesman', 'purchase_amount': '109.61990335398502', 'most bought item': 'carpet', 'labels': 'sports home books'}
# {'age': '61', 'gender': 'Female', 'income': '49355.04283382429', 'education': 'Master', 'married': 'True', 'children': '0', 'city': 'West Martha', 'occupation': 'Artist', 'purchase_amount': '86.6034234376809', 'most bought item': 'lipstick', 'labels': 'beauty electronics home'}
# {'age': '34', 'gender': 'Male', 'income': '54599.183571187', 'education': 'High School', 'married': 'True', 'children': '1', 'city': 'Austinview', 'occupation': 'HR', 'purchase_amount': '73.15260605310922', 'most bought item': 'novel', 'labels': 'books'}
# {'age': '31', 'gender': 'Male', 'income': '50614.65394535648', 'education': 'Master', 'married': 'True', 'children': '0', 'city': 'Sampsonton', 'occupation': 'Unemployed', 'purchase_amount': '101.57008974046218', 'most bought item': 'laptop', 'labels': 'electronics clothing sports'}
# {'age': '59', 'gender': 'Male', 'income': '59036.06194046724', 'education': 'Master', 'married': 'True', 'children': '2', 'city': 'South Gordonfort', 'occupation': 'Lawyer', 'purchase_amount': '102.11035710472639', 'most bought item': 'table', 'labels': 'furniture sports beauty'}
# {'age': '28', 'gender': 'Male', 'income': '50445.15412165557', 'education': 'Bachelor', 'married': 'True', 'children': '1', 'city': 'Estradaview', 'occupation': 'Lawyer', 'purchase_amount': '83.59310906937672', 'most bought item': 'shoes', 'labels': 'clothing electronics food beauty'}
# {'age': '62', 'gender': 'Female', 'income': '43882.13176346871', 'education': 'High School', 'married': 'False', 'children': '3', 'city': 'South Kristen', 'occupation': 'Unemployed', 'purchase_amount': '130.20135644276812', 'most bought item': 'chips', 'labels': 'food clothing home'}
# {'age': '42', 'gender': 'Female', 'income': '56639.40724566175', 'education': 'Bachelor', 'married': 'False', 'children': '3', 'city': 'Charleneville', 'occupation': 'Engineer', 'purchase_amount': '109.07075336679031', 'most bought item': 'novel', 'labels': 'home books'}
# {'age': '59', 'gender': 'Male', 'income': '34965.86189289492', 'education': 'PhD', 'married': 'True', 'children': '0', 'city': 'Juliatown', 'occupation': 'Retired', 'purchase_amount': '85.79361312203794', 'most bought item': 'ball', 'labels': 'sports'}
# {'age': '57', 'gender': 'Female', 'income': '72345.80098537011', 'education': 'Bachelor', 'married': 'False', 'children': '3', 'city': 'North Mistyfort', 'occupation': 'Lawyer', 'purchase_amount': '80.33583959074065', 'most bought item': 'bed', 'labels': 'beauty furniture sports'}
# {'age': '42', 'gender': 'Female', 'income': '55035.68790560127', 'education': 'Bachelor', 'married': 'True', 'children': '3', 'city': 'Bradleyfort', 'occupation': 'Businessman', 'purchase_amount': '65.47755154471508', 'most bought item': 'laptop', 'labels': 'books electronics'}
# {'age': '20', 'gender': 'Female', 'income': '34251.088241745885', 'education': 'Master', 'married': 'False', 'children': '3', 'city': 'East Blakeshire', 'occupation': 'HR', 'purchase_amount': '102.5766776337194', 'most bought item': 'dictionary', 'labels': 'electronics furniture clothing books'}
# {'age': '29', 'gender': 'Male', 'income': '64631.57099139107', 'education': 'High School', 'married': 'True', 'children': '0', 'city': 'Jonathanburgh', 'occupation': 'HR', 'purchase_amount': '96.45562329722921', 'most bought item': 'chair', 'labels': 'furniture electronics'}
# {'age': '18', 'gender': 'Female', 'income': '59967.794315528554', 'education': 'Bachelor', 'married': 'False', 'children': '2', 'city': 'Port Shellymouth', 'occupation': 'Unemployed', 'purchase_amount': '136.66211963114833', 'most bought item': 'shirt', 'labels': 'clothing'}
# {'age': '20', 'gender': 'Male', 'income': '54805.897292260335', 'education': 'Bachelor', 'married': 'False', 'children': '0', 'city': 'Anthonystad', 'occupation': 'HR', 'purchase_amount': '106.76531244820237', 'most bought item': 'maggi', 'labels': 'food'}
# {'age': '64', 'gender': 'Male', 'income': '45154.21825690305', 'education': 'Bachelor', 'married': 'False', 'children': '2', 'city': 'Buckview', 'occupation': 'Engineer', 'purchase_amount': '130.96284101842534', 'most bought item': 'mobile', 'labels': 'home electronics food books'}
# {'age': '41', 'gender': 'Male', 'income': '47743.07089598851', 'education': 'Bachelor', 'married': 'True', 'children': '1', 'city': 'South Harryhaven', 'occupation': 'Housewife', 'purchase_amount': '101.39177791302723', 'most bought item': 'ball', 'labels': 'sports'}
# {'age': '38', 'gender': 'Female', 'income': '58398.34152424912', 'education': 'Master', 'married': 'True', 'children': '3', 'city': 'Christiestad', 'occupation': 'Retired', 'purchase_amount': '106.8157666822387', 'most bought item': 'novel', 'labels': 'beauty books'}
# {'age': '63', 'gender': 'Male', 'income': '47029.70751225779', 'education': 'High School', 'married': 'True', 'children': '1', 'city': 'Port Emilyfort', 'occupation': 'Doctor', 'purchase_amount': '103.82039958874594', 'most bought item': 'biscuits', 'labels': 'books furniture food'}
# {'age': '56', 'gender': 'Male', 'income': '37581.20008285688', 'education': 'PhD', 'married': 'True', 'children': '1', 'city': 'Danielfurt', 'occupation': 'Businessman', 'purchase_amount': '105.69879000028337', 'most bought item': 'novel', 'labels': 'electronics books'}
# {'age': '19', 'gender': 'Female', 'income': '50207.088187920235', 'education': 'Bachelor', 'married': 'True', 'children': '1', 'city': 'Lake Summer', 'occupation': 'Artist', 'purchase_amount': '117.08315853161986', 'most bought item': 'chair', 'labels': 'furniture food'}
# {'age': '37', 'gender': 'Male', 'income': '36177.548600842885', 'education': 'Master', 'married': 'False', 'children': '1', 'city': 'Mossbury', 'occupation': 'Scientist', 'purchase_amount': '75.09759212958011', 'most bought item': 'shirt', 'labels': 'clothing beauty'}
# {'age': '53', 'gender': 'Female', 'income': '52297.72475799402', 'education': 'PhD', 'married': 'False', 'children': '3', 'city': 'North Thomashaven', 'occupation': 'Scientist', 'purchase_amount': '124.57436345079695', 'most bought item': 'maggi', 'labels': 'food electronics sports'}
# {'age': '42', 'gender': 'Male', 'income': '28861.045758425593', 'education': 'Bachelor', 'married': 'True', 'children': '3', 'city': 'East Michaelton', 'occupation': 'Salesman', 'purchase_amount': '97.13405699892292', 'most bought item': 'curtains', 'labels': 'home beauty'}
# {'age': '30', 'gender': 'Male', 'income': '47752.48374901555', 'education': 'Master', 'married': 'True', 'children': '1', 'city': 'West Jennifer', 'occupation': 'Lawyer', 'purchase_amount': '112.35333110033739', 'most bought item': 'table', 'labels': 'sports furniture'}
# {'age': '26', 'gender': 'Male', 'income': '55388.50391220515', 'education': 'PhD', 'married': 'False', 'children': '3', 'city': 'Lindaland', 'occupation': 'Artist', 'purchase_amount': '121.24480969208477', 'most bought item': 'shirt', 'labels': 'beauty clothing food'}
# {'age': '19', 'gender': 'Female', 'income': '58379.11735627212', 'education': 'Master', 'married': 'True', 'children': '3', 'city': 'North Caroline', 'occupation': 'Unemployed', 'purchase_amount': '88.0966031735532', 'most bought item': 'lipstick', 'labels': 'books furniture clothing beauty'}
# {'age': '26', 'gender': 'Male', 'income': '37369.758651526296', 'education': 'Master', 'married': 'True', 'children': '2', 'city': 'Rossmouth', 'occupation': 'Retired', 'purchase_amount': '80.51780528313597', 'most bought item': 'mobile', 'labels': 'electronics clothing'}
# {'age': '60', 'gender': 'Female', 'income': '52863.251164592795', 'education': 'High School', 'married': 'False', 'children': '0', 'city': 'Latoyamouth', 'occupation': 'HR', 'purchase_amount': '73.31997097607939', 'most bought item': 'chair', 'labels': 'furniture home books'}
# {'age': '25', 'gender': 'Male', 'income': '40244.79186179504', 'education': 'Master', 'married': 'True', 'children': '3', 'city': 'West Derekbury', 'occupation': 'Salesman', 'purchase_amount': '121.05054892817883', 'most bought item': 'shirt', 'labels': 'clothing food home'}
# {'age': '56', 'gender': 'Male', 'income': '52933.395091192724', 'education': 'High School', 'married': 'True', 'children': '3', 'city': 'North Ryan', 'occupation': 'Lawyer', 'purchase_amount': '88.11838935176107', 'most bought item': 'lipstick', 'labels': 'food electronics beauty books'}
# {'age': '61', 'gender': 'Male', 'income': '45173.70398776537', 'education': 'Bachelor', 'married': 'False', 'children': '0', 'city': 'Charlestown', 'occupation': 'Retired', 'purchase_amount': '69.865524457015', 'most bought item': 'laptop', 'labels': 'home electronics furniture clothing sports'}
# {'age': '35', 'gender': 'Female', 'income': '42020.980155691475', 'education': 'High School', 'married': 'True', 'children': '2', 'city': 'Lake Ann', 'occupation': 'Doctor', 'purchase_amount': '95.4600340896415', 'most bought item': 'novel', 'labels': 'sports books'}
# {'age': '46', 'gender': 'Female', 'income': '35544.71892432515', 'education': 'Master', 'married': 'True', 'children': '3', 'city': 'Josephstad', 'occupation': 'Businessman', 'purchase_amount': '119.05836082503562', 'most bought item': 'bat', 'labels': 'beauty furniture food sports books'}
# {'age': '19', 'gender': 'Female', 'income': '39170.14632314387', 'education': 'Bachelor', 'married': 'True', 'children': '1', 'city': 'Lindsayfurt', 'occupation': 'Scientist', 'purchase_amount': '116.05665044756867', 'most bought item': 'cream', 'labels': 'books furniture beauty'}
# {'age': '28', 'gender': 'Female', 'income': '28561.806366067332', 'education': 'High School', 'married': 'False', 'children': '3', 'city': 'Penastad', 'occupation': 'Lawyer', 'purchase_amount': '57.32725465766404', 'most bought item': 'mobile', 'labels': 'electronics beauty'}
# {'age': '18', 'gender': 'Female', 'income': '39919.420869221794', 'education': 'High School', 'married': 'True', 'children': '1', 'city': 'Stephaniemouth', 'occupation': 'Lawyer', 'purchase_amount': '132.3168880333956', 'most bought item': 'maggi', 'labels': 'furniture clothing food sports beauty books'}
# {'age': '24', 'gender': 'Male', 'income': '56963.66483273482', 'education': 'PhD', 'married': 'True', 'children': '1', 'city': 'South Kyle', 'occupation': 'Lawyer', 'purchase_amount': '101.67294353289198', 'most bought item': 'shirt', 'labels': 'clothing'}
# {'age': '51', 'gender': 'Female', 'income': '47598.37570753211', 'education': 'Master', 'married': 'False', 'children': '2', 'city': 'Hollandport', 'occupation': 'Engineer', 'purchase_amount': '87.55564392763273', 'most bought item': 'biscuits', 'labels': 'food furniture clothing sports'}
# {'age': '21', 'gender': 'Male', 'income': '61799.35426607131', 'education': 'PhD', 'married': 'True', 'children': '0', 'city': 'Jeffreyview', 'occupation': 'Salesman', 'purchase_amount': '99.99440953414168', 'most bought item': 'laptop', 'labels': 'home electronics food'}
# {'age': '43', 'gender': 'Male', 'income': '34228.79217218485', 'education': 'Master', 'married': 'True', 'children': '1', 'city': 'Lawrenceland', 'occupation': 'Artist', 'purchase_amount': '97.43900600074168', 'most bought item': 'curtains', 'labels': 'sports home books'}
# {'age': '20', 'gender': 'Female', 'income': '51930.31968201012', 'education': 'PhD', 'married': 'False', 'children': '2', 'city': 'Josemouth', 'occupation': 'Engineer', 'purchase_amount': '127.16043657865077', 'most bought item': 'table', 'labels': 'beauty furniture sports books'}
# {'age': '43', 'gender': 'Female', 'income': '76924.82934107931', 'education': 'High School', 'married': 'False', 'children': '1', 'city': 'Mannstad', 'occupation': 'Businessman', 'purchase_amount': '115.86873266503251', 'most bought item': 'lipstick', 'labels': 'books beauty'}
# {'age': '35', 'gender': 'Male', 'income': '58154.646025331815', 'education': 'Bachelor', 'married': 'False', 'children': '1', 'city': 'Maysport', 'occupation': 'Artist', 'purchase_amount': '131.9196771484969', 'most bought item': 'biscuits', 'labels': 'electronics furniture food'}
# {'age': '28', 'gender': 'Female', 'income': '32884.17526836677', 'education': 'Bachelor', 'married': 'False', 'children': '2', 'city': 'North Vanessa', 'occupation': 'Salesman', 'purchase_amount': '82.12934838099865', 'most bought item': 'chair', 'labels': 'furniture'}
# {'age': '49', 'gender': 'Male', 'income': '44994.23754398986', 'education': 'Master', 'married': 'True', 'children': '1', 'city': 'Adamsstad', 'occupation': 'Housewife', 'purchase_amount': '105.31721272525667', 'most bought item': 'pants', 'labels': 'clothing home books'}
# {'age': '37', 'gender': 'Female', 'income': '66667.41151126674', 'education': 'High School', 'married': 'True', 'children': '3', 'city': 'Carolynmouth', 'occupation': 'Engineer', 'purchase_amount': '106.91469460181143', 'most bought item': 'maggi', 'labels': 'food electronics'}
# {'age': '25', 'gender': 'Female', 'income': '48024.71751373533', 'education': 'Master', 'married': 'False', 'children': '3', 'city': 'New Christopherside', 'occupation': 'Scientist', 'purchase_amount': '83.67848480895628', 'most bought item': 'chair', 'labels': 'home electronics furniture food'}
# {'age': '37', 'gender': 'Female', 'income': '59131.56890402645', 'education': 'High School', 'married': 'True', 'children': '3', 'city': 'Yolandaton', 'occupation': 'Retired', 'purchase_amount': '104.37593582939124', 'most bought item': 'ball', 'labels': 'sports'}
# {'age': '43', 'gender': 'Female', 'income': '48004.02667859703', 'education': 'PhD', 'married': 'True', 'children': '1', 'city': 'West Amanda', 'occupation': 'Scientist', 'purchase_amount': '97.67351330948136', 'most bought item': 'lipstick', 'labels': 'beauty'}
# {'age': '21', 'gender': 'Female', 'income': '40825.92690558694', 'education': 'Bachelor', 'married': 'True', 'children': '2', 'city': 'Port Georgeview', 'occupation': 'HR', 'purchase_amount': '85.20508296914205', 'most bought item': 'perfume', 'labels': 'books electronics clothing food beauty'}
# {'age': '22', 'gender': 'Male', 'income': '61574.558322846686', 'education': 'Master', 'married': 'False', 'children': '2', 'city': 'Bishopchester', 'occupation': 'Housewife', 'purchase_amount': '85.53811194832929', 'most bought item': 'laptop', 'labels': 'electronics'}
# {'age': '54', 'gender': 'Male', 'income': '53155.35250270695', 'education': 'High School', 'married': 'True', 'children': '0', 'city': 'Shelbyburgh', 'occupation': 'Lawyer', 'purchase_amount': '143.68287280620157', 'most bought item': 'bed', 'labels': 'furniture electronics'}
# {'age': '35', 'gender': 'Male', 'income': '56620.4177051776', 'education': 'Master', 'married': 'True', 'children': '2', 'city': 'East Ryanstad', 'occupation': 'Artist', 'purchase_amount': '117.04479051312977', 'most bought item': 'shirt', 'labels': 'clothing'}
# {'age': '36', 'gender': 'Male', 'income': '56469.440625551135', 'education': 'Bachelor', 'married': 'True', 'children': '1', 'city': 'Kathyport', 'occupation': 'Businessman', 'purchase_amount': '92.08922059000238', 'most bought item': 'chips', 'labels': 'food home beauty'}
# {'age': '63', 'gender': 'Male', 'income': '58872.1412178482', 'education': 'Bachelor', 'married': 'True', 'children': '2', 'city': 'Adamchester', 'occupation': 'Businessman', 'purchase_amount': '72.28416466641877', 'most bought item': 'dictionary', 'labels': 'home beauty books'}
# {'age': '40', 'gender': 'Male', 'income': '49712.239712718205', 'education': 'Bachelor', 'married': 'False', 'children': '1', 'city': 'North James', 'occupation': 'Scientist', 'purchase_amount': '98.65653776206403', 'most bought item': 'novel', 'labels': 'sports clothing books'}
# {'age': '29', 'gender': 'Female', 'income': '56094.52476475081', 'education': 'PhD', 'married': 'True', 'children': '0', 'city': 'West Anaside', 'occupation': 'Lawyer', 'purchase_amount': '79.25226145311936', 'most bought item': 'cream', 'labels': 'beauty'}
# {'age': '35', 'gender': 'Male', 'income': '48182.076856045605', 'education': 'Bachelor', 'married': 'True', 'children': '3', 'city': 'North Josephmouth', 'occupation': 'Businessman', 'purchase_amount': '104.05842481995458', 'most bought item': 'dictionary', 'labels': 'books'}
# {'age': '20', 'gender': 'Female', 'income': '43764.52125748605', 'education': 'Master', 'married': 'True', 'children': '0', 'city': 'New Josephbury', 'occupation': 'Unemployed', 'purchase_amount': '79.34265249970305', 'most bought item': 'laptop', 'labels': 'electronics furniture clothing'}
# {'age': '61', 'gender': 'Female', 'income': '63204.60055200507', 'education': 'PhD', 'married': 'False', 'children': '1', 'city': 'Nelsonfurt', 'occupation': 'Engineer', 'purchase_amount': '95.53423976583518', 'most bought item': 'bed', 'labels': 'furniture electronics beauty'}
# {'age': '47', 'gender': 'Female', 'income': '31942.00315126836', 'education': 'Bachelor', 'married': 'False', 'children': '2', 'city': 'North Kimberly', 'occupation': 'Retired', 'purchase_amount': '97.41656327803004', 'most bought item': 'pants', 'labels': 'clothing'}
# {'age': '56', 'gender': 'Female', 'income': '48322.15365584005', 'education': 'Bachelor', 'married': 'False', 'children': '1', 'city': 'Meyermouth', 'occupation': 'Engineer', 'purchase_amount': '160.897159355984', 'most bought item': 'maggi', 'labels': 'food'}
# {'age': '28', 'gender': 'Female', 'income': '37105.50531457811', 'education': 'Bachelor', 'married': 'True', 'children': '3', 'city': 'West Jimmy', 'occupation': 'Engineer', 'purchase_amount': '105.88634349908172', 'most bought item': 'curtains', 'labels': 'home food'}
# {'age': '23', 'gender': 'Male', 'income': '38509.32990814546', 'education': 'High School', 'married': 'True', 'children': '3', 'city': 'Port Samantha', 'occupation': 'Artist', 'purchase_amount': '95.72730350132514', 'most bought item': 'sofa', 'labels': 'sports home'}
# {'age': '27', 'gender': 'Female', 'income': '65173.54620630821', 'education': 'Bachelor', 'married': 'False', 'children': '0', 'city': 'New Brooke', 'occupation': 'Doctor', 'purchase_amount': '113.80760925033498', 'most bought item': 'lipstick', 'labels': 'beauty furniture'}
# {'age': '23', 'gender': 'Female', 'income': '54976.46461051306', 'education': 'High School', 'married': 'True', 'children': '2', 'city': 'South Stephen', 'occupation': 'Housewife', 'purchase_amount': '97.53958768570693', 'most bought item': 'encyclopedia', 'labels': 'books clothing beauty'}
# {'age': '50', 'gender': 'Male', 'income': '37941.65210752496', 'education': 'PhD', 'married': 'True', 'children': '2', 'city': 'Ashleymouth', 'occupation': 'Retired', 'purchase_amount': '122.86901572018128', 'most bought item': 'dictionary', 'labels': 'electronics books'}
# {'age': '42', 'gender': 'Female', 'income': '57927.26103794576', 'education': 'Master', 'married': 'False', 'children': '0', 'city': 'Russellburgh', 'occupation': 'Lawyer', 'purchase_amount': '87.42069172216185', 'most bought item': 'shirt', 'labels': 'furniture clothing food beauty'}
# {'age': '33', 'gender': 'Female', 'income': '59907.215676412095', 'education': 'Bachelor', 'married': 'True', 'children': '0', 'city': 'Michelleport', 'occupation': 'Scientist', 'purchase_amount': '77.33775888083545', 'most bought item': 'shoes', 'labels': 'clothing food sports'}
# {'age': '40', 'gender': 'Male', 'income': '40544.47583357694', 'education': 'Master', 'married': 'True', 'children': '0', 'city': 'Jenningsmouth', 'occupation': 'Doctor', 'purchase_amount': '76.52994461528864', 'most bought item': 'chips', 'labels': 'food'}
# {'age': '46', 'gender': 'Female', 'income': '42805.49284357016', 'education': 'Bachelor', 'married': 'True', 'children': '2', 'city': 'Housebury', 'occupation': 'Lawyer', 'purchase_amount': '88.39364037812132', 'most bought item': 'cream', 'labels': 'home furniture food beauty'}
# {'age': '64', 'gender': 'Male', 'income': '61381.60340443374', 'education': 'Master', 'married': 'False', 'children': '2', 'city': 'East Maria', 'occupation': 'Retired', 'purchase_amount': '82.46240386282504', 'most bought item': 'ball', 'labels': 'sports'}
# {'age': '28', 'gender': 'Male', 'income': '55586.95770104409', 'education': 'Master', 'married': 'True', 'children': '3', 'city': 'Briannachester', 'occupation': 'Businessman', 'purchase_amount': '134.06348163858328', 'most bought item': 'pants', 'labels': 'beauty furniture clothing'}
# {'age': '59', 'gender': 'Female', 'income': '58732.59608234798', 'education': 'PhD', 'married': 'True', 'children': '0', 'city': 'Lake Mike', 'occupation': 'Artist', 'purchase_amount': '119.48387774439088', 'most bought item': 'dictionary', 'labels': 'books furniture food'}
# {'age': '28', 'gender': 'Male', 'income': '37177.542362421314', 'education': 'Bachelor', 'married': 'False', 'children': '1', 'city': 'East Amanda', 'occupation': 'Unemployed', 'purchase_amount': '80.1122522855367', 'most bought item': 'dictionary', 'labels': 'electronics sports books'}
# {'age': '18', 'gender': 'Female', 'income': '57373.84165713485', 'education': 'High School', 'married': 'False', 'children': '2', 'city': 'Nguyenton', 'occupation': 'Businessman', 'purchase_amount': '120.88609708875002', 'most bought item': 'lipstick', 'labels': 'furniture clothing sports beauty'}
# {'age': '57', 'gender': 'Female', 'income': '48119.143314656474', 'education': 'PhD', 'married': 'False', 'children': '0', 'city': 'West Jon', 'occupation': 'HR', 'purchase_amount': '123.84689153774136', 'most bought item': 'chips', 'labels': 'clothing electronics furniture food home sports books'}
# {'age': '59', 'gender': 'Male', 'income': '35559.61354099553', 'education': 'Bachelor', 'married': 'False', 'children': '3', 'city': 'South Garrett', 'occupation': 'Salesman', 'purchase_amount': '116.14379689525697', 'most bought item': 'chips', 'labels': 'food electronics home'}
# {'age': '32', 'gender': 'Male', 'income': '44594.677803879356', 'education': 'Master', 'married': 'False', 'children': '3', 'city': 'Roseville', 'occupation': 'Scientist', 'purchase_amount': '115.10709879086576', 'most bought item': 'sofa', 'labels': 'home'}
# {'age': '34', 'gender': 'Female', 'income': '50828.329692849125', 'education': 'Bachelor', 'married': 'False', 'children': '1', 'city': 'South Timothyhaven', 'occupation': 'Doctor', 'purchase_amount': '73.58187046136766', 'most bought item': 'ball', 'labels': 'sports'}
# {'age': '29', 'gender': 'Female', 'income': '43998.658288791274', 'education': 'High School', 'married': 'True', 'children': '1', 'city': 'North Eric', 'occupation': 'Doctor', 'purchase_amount': '122.63246344952324', 'most bought item': 'biscuits', 'labels': 'beauty furniture food'}
# {'age': '26', 'gender': 'Male', 'income': '48084.25063793769', 'education': 'Bachelor', 'married': 'False', 'children': '1', 'city': 'Port Darrellbury', 'occupation': 'Doctor', 'purchase_amount': '97.3301923792665', 'most bought item': 'dictionary', 'labels': 'books home'}
# {'age': '51', 'gender': 'Male', 'income': '45883.30335613441', 'education': 'High School', 'married': 'False', 'children': '3', 'city': 'Taylormouth', 'occupation': 'Scientist', 'purchase_amount': '94.14246090800101', 'most bought item': 'bat', 'labels': 'electronics clothing home sports beauty'}
# {'age': '48', 'gender': 'Male', 'income': '37206.84992790919', 'education': 'High School', 'married': 'True', 'children': '1', 'city': 'West Lisaport', 'occupation': 'Artist', 'purchase_amount': '104.25376890094337', 'most bought item': 'chair', 'labels': 'furniture beauty'}
# {'age': '39', 'gender': 'Male', 'income': '66729.59290028003', 'education': 'Master', 'married': 'True', 'children': '2', 'city': 'East Matthewshire', 'occupation': 'Businessman', 'purchase_amount': '115.43277317856996', 'most bought item': 'shoes', 'labels': 'clothing food sports'}
# {'age': '39', 'gender': 'Male', 'income': '40442.82803464994', 'education': 'Bachelor', 'married': 'False', 'children': '3', 'city': 'Kellerfurt', 'occupation': 'HR', 'purchase_amount': '130.7067487425539', 'most bought item': 'maggi', 'labels': 'food clothing sports'}
# ...
# {'age': '41', 'gender': 'Male', 'income': '36747.1525209805', 'education': 'High School', 'married': 'False', 'children': '3', 'city': 'New Marthaberg', 'occupation': 'Artist', 'purchase_amount': '95.70202264470677', 'most bought item': 'novel', 'labels': 'books electronics food home'}
# {'age': '53', 'gender': 'Male', 'income': '34314.17917251573', 'education': 'Bachelor', 'married': 'False', 'children': '1', 'city': 'Lake Cindy', 'occupation': 'Lawyer', 'purchase_amount': '96.24220371146916', 'most bought item': 'mobile', 'labels': 'electronics food'}
# {'age': '41', 'gender': 'Female', 'income': '52459.68039800273', 'education': 'PhD', 'married': 'True', 'children': '0', 'city': 'South Stacy', 'occupation': 'Businessman', 'purchase_amount': '100.25197385432752', 'most bought item': 'bed', 'labels': 'furniture sports beauty'}
# {'age': '55', 'gender': 'Female', 'income': '59099.57775260885', 'education': 'PhD', 'married': 'False', 'children': '2', 'city': 'Jacobburgh', 'occupation': 'Retired', 'purchase_amount': '108.90597957629566', 'most bought item': 'curtains', 'labels': 'clothing furniture food home books'}
# {'age': '35', 'gender': 'Male', 'income': '38112.956404547345', 'education': 'Master', 'married': 'False', 'children': '0', 'city': 'South Lorraine', 'occupation': 'Scientist', 'purchase_amount': '81.5748378352676', 'most bought item': 'pants', 'labels': 'food electronics clothing'}
# {'age': '56', 'gender': 'Male', 'income': '48651.43455091765', 'education': 'Master', 'married': 'False', 'children': '0', 'city': 'Cruzport', 'occupation': 'Scientist', 'purchase_amount': '102.69884202709436', 'most bought item': 'encyclopedia', 'labels': 'home food books'}
# {'age': '20', 'gender': 'Male', 'income': '41225.92997448343', 'education': 'Master', 'married': 'True', 'children': '2', 'city': 'West Aimee', 'occupation': 'Housewife', 'purchase_amount': '58.10285900305949', 'most bought item': 'pants', 'labels': 'sports furniture clothing home beauty'}
# {'age': '49', 'gender': 'Female', 'income': '59344.5811843784', 'education': 'Master', 'married': 'True', 'children': '3', 'city': 'New Michellefort', 'occupation': 'Salesman', 'purchase_amount': '94.8087597994815', 'most bought item': 'perfume', 'labels': 'beauty'}
# {'age': '45', 'gender': 'Male', 'income': '42395.70803402599', 'education': 'Master', 'married': 'True', 'children': '2', 'city': 'Lake Garrett', 'occupation': 'Unemployed', 'purchase_amount': '115.65463938384431', 'most bought item': 'bat', 'labels': 'books sports beauty'}
# {'age': '59', 'gender': 'Male', 'income': '51452.53855134162', 'education': 'PhD', 'married': 'True', 'children': '1', 'city': 'Port Justin', 'occupation': 'Scientist', 'purchase_amount': '86.0479059726877', 'most bought item': 'sofa', 'labels': 'electronics home beauty books'}
# {'age': '59', 'gender': 'Female', 'income': '53678.04381726076', 'education': 'PhD', 'married': 'True', 'children': '2', 'city': 'West Carrieview', 'occupation': 'Businessman', 'purchase_amount': '81.96431522635423', 'most bought item': 'biscuits', 'labels': 'furniture food'}
# {'age': '18', 'gender': 'Female', 'income': '44881.10927621864', 'education': 'Master', 'married': 'False', 'children': '0', 'city': 'Johnsonview', 'occupation': 'Unemployed', 'purchase_amount': '84.09060740840144', 'most bought item': 'pants', 'labels': 'clothing home books'}
# {'age': '21', 'gender': 'Female', 'income': '40084.10441610245', 'education': 'Master', 'married': 'True', 'children': '1', 'city': 'Castillostad', 'occupation': 'Housewife', 'purchase_amount': '79.75326443871772', 'most bought item': 'mobile', 'labels': 'food electronics furniture sports beauty'}
# {'age': '64', 'gender': 'Male', 'income': '43973.55008493944', 'education': 'Master', 'married': 'True', 'children': '1', 'city': 'South Erica', 'occupation': 'Salesman', 'purchase_amount': '82.24469284775813', 'most bought item': 'shirt', 'labels': 'home electronics clothing'}
# {'age': '27', 'gender': 'Female', 'income': '54162.518497704325', 'education': 'High School', 'married': 'False', 'children': '3', 'city': 'West Mckenzieborough', 'occupation': 'Artist', 'purchase_amount': '101.36380253679779', 'most bought item': 'ball', 'labels': 'sports electronics books'}
# {'age': '36', 'gender': 'Male', 'income': '42746.84587125786', 'education': 'PhD', 'married': 'False', 'children': '2', 'city': 'Garyfurt', 'occupation': 'HR', 'purchase_amount': '85.85883218940333', 'most bought item': 'table', 'labels': 'beauty furniture sports books'}
# {'age': '59', 'gender': 'Female', 'income': '51890.2872349272', 'education': 'Master', 'married': 'False', 'children': '3', 'city': 'Chaneystad', 'occupation': 'Doctor', 'purchase_amount': '95.02903847874539', 'most bought item': 'carpet', 'labels': 'books home'}
# {'age': '38', 'gender': 'Male', 'income': '53990.72471829079', 'education': 'Master', 'married': 'True', 'children': '0', 'city': 'West Robert', 'occupation': 'Housewife', 'purchase_amount': '102.79946236937433', 'most bought item': 'mobile', 'labels': 'electronics beauty'}
# {'age': '64', 'gender': 'Male', 'income': '56949.73704120083', 'education': 'Bachelor', 'married': 'False', 'children': '0', 'city': 'South Carolynside', 'occupation': 'Housewife', 'purchase_amount': '104.97875425822704', 'most bought item': 'bed', 'labels': 'furniture electronics'}
# {'age': '48', 'gender': 'Female', 'income': '51428.476388078605', 'education': 'PhD', 'married': 'True', 'children': '0', 'city': 'Davidborough', 'occupation': 'Engineer', 'purchase_amount': '110.24752036226852', 'most bought item': 'ball', 'labels': 'clothing electronics food sports'}
# {'age': '56', 'gender': 'Female', 'income': '44928.44333791607', 'education': 'Bachelor', 'married': 'False', 'children': '1', 'city': 'Melissaberg', 'occupation': 'Engineer', 'purchase_amount': '107.88263877447532', 'most bought item': 'curtains', 'labels': 'food home books'}
# {'age': '64', 'gender': 'Male', 'income': '49157.077152678445', 'education': 'Bachelor', 'married': 'False', 'children': '3', 'city': 'East Barbaraburgh', 'occupation': 'Unemployed', 'purchase_amount': '96.07804695844678', 'most bought item': 'encyclopedia', 'labels': 'home books'}
# {'age': '19', 'gender': 'Male', 'income': '51009.24539969646', 'education': 'Master', 'married': 'True', 'children': '2', 'city': 'Tammymouth', 'occupation': 'HR', 'purchase_amount': '130.176055880121', 'most bought item': 'novel', 'labels': 'sports electronics beauty books'}
# {'age': '59', 'gender': 'Male', 'income': '33044.95188489255', 'education': 'PhD', 'married': 'False', 'children': '3', 'city': 'East Lindafort', 'occupation': 'Retired', 'purchase_amount': '103.53947088391035', 'most bought item': 'maggi', 'labels': 'beauty furniture food books'}
# {'age': '54', 'gender': 'Male', 'income': '58995.94798576523', 'education': 'Master', 'married': 'True', 'children': '2', 'city': 'Port Ryan', 'occupation': 'Scientist', 'purchase_amount': '121.49268200731814', 'most bought item': 'novel', 'labels': 'books electronics sports'}
# {'age': '41', 'gender': 'Male', 'income': '50891.77881833846', 'education': 'PhD', 'married': 'True', 'children': '0', 'city': 'North Davidburgh', 'occupation': 'Engineer', 'purchase_amount': '130.04988856657795', 'most bought item': 'chips', 'labels': 'electronics furniture clothing food sports'}
# {'age': '27', 'gender': 'Female', 'income': '58940.332769120054', 'education': 'PhD', 'married': 'False', 'children': '3', 'city': 'East Christopherstad', 'occupation': 'Retired', 'purchase_amount': '100.1527859386344', 'most bought item': 'bed', 'labels': 'furniture electronics food home'}
# {'age': '54', 'gender': 'Female', 'income': '67071.87088156326', 'education': 'Bachelor', 'married': 'False', 'children': '0', 'city': 'South Ashleyhaven', 'occupation': 'Scientist', 'purchase_amount': '82.32272480346194', 'most bought item': 'pants', 'labels': 'clothing'}
# {'age': '41', 'gender': 'Female', 'income': '56957.35193003291', 'education': 'High School', 'married': 'True', 'children': '1', 'city': 'Tuckerbury', 'occupation': 'Salesman', 'purchase_amount': '41.975823091935425', 'most bought item': 'sofa', 'labels': 'food home sports beauty'}
# {'age': '28', 'gender': 'Female', 'income': '48261.63545013206', 'education': 'High School', 'married': 'True', 'children': '2', 'city': 'North Joshua', 'occupation': 'Housewife', 'purchase_amount': '79.90360833403892', 'most bought item': 'carpet', 'labels': 'home'}
# {'age': '43', 'gender': 'Male', 'income': '48961.90600566573', 'education': 'PhD', 'married': 'True', 'children': '3', 'city': 'Xavierbury', 'occupation': 'HR', 'purchase_amount': '94.51203628352928', 'most bought item': 'ball', 'labels': 'sports'}
# {'age': '33', 'gender': 'Female', 'income': '56901.84719924685', 'education': 'Bachelor', 'married': 'False', 'children': '3', 'city': 'Sarahmouth', 'occupation': 'Unemployed', 'purchase_amount': '115.34786223927557', 'most bought item': 'lipstick', 'labels': 'beauty'}
# {'age': '55', 'gender': 'Male', 'income': '41957.92957957794', 'education': 'Master', 'married': 'False', 'children': '0', 'city': 'North Markbury', 'occupation': 'Retired', 'purchase_amount': '114.98490592290315', 'most bought item': 'bed', 'labels': 'books furniture food'}
# {'age': '43', 'gender': 'Female', 'income': '52565.61536438526', 'education': 'PhD', 'married': 'False', 'children': '3', 'city': 'East Samuel', 'occupation': 'Businessman', 'purchase_amount': '101.29028073237842', 'most bought item': 'novel', 'labels': 'electronics food sports books'}
# {'age': '45', 'gender': 'Male', 'income': '39452.161582983856', 'education': 'Master', 'married': 'True', 'children': '2', 'city': 'Alexiston', 'occupation': 'Scientist', 'purchase_amount': '91.51432876029803', 'most bought item': 'monitor', 'labels': 'furniture electronics books'}
# {'age': '51', 'gender': 'Female', 'income': '42604.10554862373', 'education': 'PhD', 'married': 'True', 'children': '3', 'city': 'Janeborough', 'occupation': 'Lawyer', 'purchase_amount': '91.28386848458584', 'most bought item': 'shirt', 'labels': 'clothing'}
# {'age': '31', 'gender': 'Female', 'income': '38102.45561787404', 'education': 'Master', 'married': 'False', 'children': '2', 'city': 'South Tylerhaven', 'occupation': 'Housewife', 'purchase_amount': '93.402013278787', 'most bought item': 'maggi', 'labels': 'food electronics clothing beauty'}
# {'age': '37', 'gender': 'Female', 'income': '50318.20825127652', 'education': 'Bachelor', 'married': 'True', 'children': '2', 'city': 'Englishshire', 'occupation': 'Artist', 'purchase_amount': '127.03661662488274', 'most bought item': 'dictionary', 'labels': 'home food sports books'}
# {'age': '46', 'gender': 'Female', 'income': '58864.68402354271', 'education': 'High School', 'married': 'False', 'children': '2', 'city': 'Kelliehaven', 'occupation': 'Retired', 'purchase_amount': '93.64940231186462', 'most bought item': 'laptop', 'labels': 'sports electronics home beauty'}
# {'age': '35', 'gender': 'Female', 'income': '38610.66206403775', 'education': 'PhD', 'married': 'True', 'children': '3', 'city': 'Graytown', 'occupation': 'Lawyer', 'purchase_amount': '88.02995166616932', 'most bought item': 'lipstick', 'labels': 'beauty electronics'}
# {'age': '27', 'gender': 'Male', 'income': '52399.283682960886', 'education': 'PhD', 'married': 'False', 'children': '1', 'city': 'Lake Becky', 'occupation': 'HR', 'purchase_amount': '106.1167128038864', 'most bought item': 'encyclopedia', 'labels': 'books home beauty'}
# {'age': '23', 'gender': 'Female', 'income': '37874.864649034345', 'education': 'Bachelor', 'married': 'False', 'children': '1', 'city': 'West Elizabeth', 'occupation': 'Doctor', 'purchase_amount': '92.39978577046698', 'most bought item': 'monitor', 'labels': 'electronics beauty'}
# {'age': '46', 'gender': 'Female', 'income': '43494.165780795716', 'education': 'Bachelor', 'married': 'True', 'children': '1', 'city': 'North Andrew', 'occupation': 'Housewife', 'purchase_amount': '99.22592182255782', 'most bought item': 'perfume', 'labels': 'furniture home sports beauty'}
# {'age': '25', 'gender': 'Male', 'income': '37364.32371589512', 'education': 'PhD', 'married': 'True', 'children': '2', 'city': 'Michaelberg', 'occupation': 'HR', 'purchase_amount': '95.6491386518574', 'most bought item': 'shoes', 'labels': 'clothing'}
# {'age': '57', 'gender': 'Female', 'income': '66021.79156986217', 'education': 'Bachelor', 'married': 'True', 'children': '1', 'city': 'East Deannaberg', 'occupation': 'Housewife', 'purchase_amount': '99.43765561962559', 'most bought item': 'laptop', 'labels': 'food electronics home'}
# {'age': '45', 'gender': 'Male', 'income': '47324.47188544186', 'education': 'High School', 'married': 'False', 'children': '2', 'city': 'Perryview', 'occupation': 'Doctor', 'purchase_amount': '76.76475259303902', 'most bought item': 'sofa', 'labels': 'home electronics beauty'}
# {'age': '24', 'gender': 'Female', 'income': '45799.425423911125', 'education': 'High School', 'married': 'False', 'children': '2', 'city': 'Glovermouth', 'occupation': 'HR', 'purchase_amount': '124.49628766831741', 'most bought item': 'bed', 'labels': 'sports furniture'}
# {'age': '19', 'gender': 'Female', 'income': '53929.9266212794', 'education': 'High School', 'married': 'False', 'children': '1', 'city': 'Lake Anthony', 'occupation': 'HR', 'purchase_amount': '135.06753914110413', 'most bought item': 'table', 'labels': 'beauty furniture'}
# {'age': '32', 'gender': 'Male', 'income': '43606.4855511904', 'education': 'Bachelor', 'married': 'True', 'children': '3', 'city': 'West Richard', 'occupation': 'Housewife', 'purchase_amount': '33.15460762453873', 'most bought item': 'encyclopedia', 'labels': 'books sports'}
# {'age': '54', 'gender': 'Male', 'income': '52316.526988769154', 'education': 'High School', 'married': 'True', 'children': '3', 'city': 'Claytonstad', 'occupation': 'Salesman', 'purchase_amount': '103.70559301035252', 'most bought item': 'mobile', 'labels': 'electronics furniture food home sports'}
# {'age': '51', 'gender': 'Male', 'income': '36943.241990731', 'education': 'Bachelor', 'married': 'True', 'children': '1', 'city': 'Tinaburgh', 'occupation': 'Doctor', 'purchase_amount': '130.89617655787703', 'most bought item': 'carpet', 'labels': 'furniture home'}
# {'age': '31', 'gender': 'Male', 'income': '35741.448957622626', 'education': 'High School', 'married': 'True', 'children': '0', 'city': 'Kellyfurt', 'occupation': 'Scientist', 'purchase_amount': '82.55091133309779', 'most bought item': 'shoes', 'labels': 'clothing books'}
# {'age': '61', 'gender': 'Male', 'income': '34246.77306326943', 'education': 'Master', 'married': 'True', 'children': '3', 'city': 'Solisfurt', 'occupation': 'HR', 'purchase_amount': '103.35744082070975', 'most bought item': 'bed', 'labels': 'food furniture'}
# {'age': '56', 'gender': 'Female', 'income': '45494.22559124395', 'education': 'Bachelor', 'married': 'False', 'children': '0', 'city': 'Dawsonmouth', 'occupation': 'Engineer', 'purchase_amount': '85.1590227224369', 'most bought item': 'biscuits', 'labels': 'home clothing food'}
# {'age': '64', 'gender': 'Female', 'income': '68740.44200637276', 'education': 'PhD', 'married': 'True', 'children': '0', 'city': 'Lake Garyport', 'occupation': 'Salesman', 'purchase_amount': '101.4346500112247', 'most bought item': 'bat', 'labels': 'sports clothing'}
# {'age': '18', 'gender': 'Female', 'income': '44348.446679939334', 'education': 'Bachelor', 'married': 'True', 'children': '0', 'city': 'Ericfurt', 'occupation': 'Retired', 'purchase_amount': '97.64998780156691', 'most bought item': 'perfume', 'labels': 'beauty'}
# {'age': '61', 'gender': 'Male', 'income': '39160.08367652033', 'education': 'Master', 'married': 'False', 'children': '0', 'city': 'Port Jose', 'occupation': 'Housewife', 'purchase_amount': '105.59148548653422', 'most bought item': 'shirt', 'labels': 'books clothing'}

# %%
#Load dataset using Pandas Library

#Source- Chatgpt and Stack Overflow: Loading the dataset again using Pandas as further steps mentioned in Assignment document become simpler and easier to analyse.
#Prompt given to Chatgpt: Data Visualization using Pandas, and state it's advantages. Give basic outline of data visualization, preprocessing , featurization, train-val-test splitting
# Both DictReader and Pandas are used for analysing a csv data but DictReader requires more manual work for tasks like filtering, grouping, joining, and other common data processing operations. 
# Whereas using pandas would be much more efficient and straightforward. The majority of data science and machine learning workflows in Python leverage pandas due to its versatility and efficiency.

#Below is the code for loading dataset using Pandas

# data visualization and exploration
import numpy as np
import pandas as pd

# Load the dataset from CSV file
data_dt = pd.read_csv('/home/aishani/Documents/GitHub/SMAI-Assignment-1/SMAI ASSIGNMENT 1/advertisement.csv')
print(data_dt.head())
print(data_dt['labels'].value_counts())
print(data_dt.describe())

#View shape
print("Data Shape:", data_dt.shape)

import matplotlib.pyplot as plt

# 1. Histograms
numerical_features = data_dt.select_dtypes(include=[np.number]).columns.tolist()
for feature in numerical_features:
    plt.hist(data_dt[feature], bins=30, edgecolor='black')
    plt.title(f'Histogram of {feature}')
    plt.xlabel(feature)
    plt.ylabel('Frequency')
    plt.show()

# 2. Bar Charts
categorical_features = data_dt.select_dtypes(include=['object']).columns.tolist()
for feature in categorical_features:
    data_dt[feature].value_counts().plot(kind='bar')
    plt.title(f'Bar Chart of {feature}')
    plt.xlabel(feature)
    plt.ylabel('Frequency')
    plt.show()

# 3. Correlation Matrix
correlation_matrix = data_dt[numerical_features].corr()
plt.imshow(correlation_matrix, cmap='coolwarm', interpolation='none')
plt.colorbar()
plt.xticks(range(len(correlation_matrix)), correlation_matrix.columns, rotation=90)
plt.yticks(range(len(correlation_matrix)), correlation_matrix.columns)
plt.title('Correlation Matrix')
plt.show()

# 4. Box Plots
for feature in numerical_features:
    data_dt.boxplot(column=feature, by='labels')  # Replace 'labels' with your actual label column name if different
    plt.title(f'Box Plot of {feature}')
    plt.suptitle('')  # Suppress default title
    plt.show()

# 5. Scatter Plots
# Using scatter_matrix from pandas for pairwise scatter plots
from pandas.plotting import scatter_matrix
scatter_matrix(data_dt[numerical_features], figsize=(10, 10), diagonal='hist', cmap='coolwarm')
plt.suptitle('Pairwise Scatter Plots')
plt.show()
print("Data visualization and exploration complete")
# Out:
#    age  gender        income    education  married  children           city  \
# 0   45    Male  61271.953359       Master    False         3    Lake Sheila
# 1   24  Female  53229.101074  High School    False         1   Crystalburgh
# 2   45  Female  30066.046684     Bachelor     True         3  Margaretburgh
# 3   19    Male  48950.246384          PhD    False         0  Williamshaven
# 4   29  Female  44792.627094       Master    False         0       New Paul
#
#     occupation  purchase_amount most bought item  \
# 0       Doctor        87.697118          monitor
# 1  Businessman       115.135586         lipstick
# 2     Engineer       101.694559         biscuits
# 3       Lawyer        97.964887            maggi
# 4  Businessman        86.847281           carpet
#
#                              labels
# 0       electronics clothing sports
# 1                  furniture beauty
# 2  clothing electronics food sports
# 3                              food
# 4                              home
# labels
# sports                                        24
# clothing                                      23
# beauty                                        20
# electronics                                   17
# home                                          15
#                                               ..
# beauty clothing home                           1
# books electronics clothing food                1
# furniture electronics clothing home sports     1
# sports electronics furniture books             1
# electronics furniture food home sports         1
# Name: count, Length: 397, dtype: int64
#                age        income     children  purchase_amount
# count  1000.000000   1000.000000  1000.000000      1000.000000
# mean     40.836000  49349.796167     1.508000       101.098170
# std      13.786848   9894.479148     1.129253        20.348736
# min      18.000000  21908.867759     0.000000        23.482179
# 25%      28.000000  42577.352034     0.000000        87.699577
# 50%      41.000000  48993.757137     1.000000       101.587560
# 75%      53.000000  56566.795992     3.000000       114.718926
# max      64.000000  79459.294416     3.000000       168.978628
# Data Shape: (1000, 11)
# Data visualization and exploration complete

# %%
data_dt.info() #View summary/information of data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   age               1000 non-null   int64
#  1   gender            1000 non-null   object
#  2   income            1000 non-null   float64
#  3   education         1000 non-null   object
#  4   married           1000 non-null   bool
#  5   children          1000 non-null   int64
#  6   city              1000 non-null   object
#  7   occupation        1000 non-null   object
#  8   purchase_amount   1000 non-null   float64
#  9   most bought item  1000 non-null   object
#  10  labels            1000 non-null   object
# dtypes: bool(1), float64(2), int64(2), object(6)
# memory usage: 79.2+ KB

# %%
#Below is the implementation of 3.3.1 Task 1


####################################################################################################################################################################

'''  

SOURCE - CHATGPT 

Why I used Chatgpt:
I wrote the below code for data preprocessing and data featurization:

"
# Load data
data_dt = pd.read_csv('/home/aishani/Documents/GitHub/SMAI-Assignment-1/SMAI ASSIGNMENT 1/advertisement.csv')

# Data preprocessing
# 1. Handling Missing Values
for column in data_dt.select_dtypes(include=[np.number]).columns:
    data_dt[column].fillna(data_dt[column].median(), inplace=True)
# 2. Removing Duplicates
data_dt.drop_duplicates(inplace=True)
# 3. Outlier Removal (using Z-score)
z_scores = np.abs(stats.zscore(data_dt.select_dtypes(include=[np.number])))
data_dt = data_dt[(z_scores < 3).all(axis=1)]

# Encoding categorical variables
label_encoder = LabelEncoder()
for column in data_dt.select_dtypes(include=['object']).columns:
    if column != 'labels':
        data_dt[column] = label_encoder.fit_transform(data_dt[column])

print("Data Preprocessing complete.")

# Limit to first 10 unique labels for demonstration
unique_labels = list(set([item for sublist in data_dt['labels'].str.split(', ') for item in sublist]))
limited_labels = unique_labels[:10]

# Count how many rows contain the limited labels
count_rows_with_limited_labels = data_dt['labels'].apply(lambda x: len(set(x.split(', ')) & set(limited_labels)) > 0).sum()
print("Rows with limited labels:", count_rows_with_limited_labels)

# Filter rows so that only limited labels are included
data_dt['labels'] = data_dt['labels'].str.split(', ').apply(lambda x: list(set(x) & set(limited_labels)))

# Remove rows with no labels after filtering
data_dt = data_dt[data_dt['labels'].apply(len) > 0]

# Data Featurization (interaction terms)
data_dt['age_income'] = data_dt['age'] * data_dt['income']
data_dt['age_children'] = data_dt['age'] * data_dt['children']
data_dt['income_children'] = data_dt['income'] * data_dt['children']
data_dt['income_purchase_amount'] = data_dt['income'] * data_dt['purchase_amount']

print("Data Featurization complete. Added interaction terms.")

# Separate features and target variable
X = data_dt.drop(['labels'], axis=1)
y = data_dt['labels']

# Convert labels to indicator matrix
mlb = MultiLabelBinarizer()

# Separate features and target variable
X = data_dt.drop(['labels'], axis=1)
y = data_dt['labels']

# Convert labels to indicator matrix
mlb = MultiLabelBinarizer()
y_indicator = mlb.fit_transform(y)
# y_test_binarized = mlb.tranform (y_test)
"

But my VS Code kept crashing. Reason for it was that it was using a lot of CPU time and heavy computation for forming powersets.

Prompt given to ChatGPT:

I wrote the below code:
"
def custom_f1_score(y_true, y_pred):
    TP = np.sum((y_true == 1) & (y_pred == 1), axis=0)
    FP = np.sum((y_true == 0) & (y_pred == 1), axis=0)
    FN = np.sum((y_true == 1) & (y_pred == 0), axis=0)
    
    precision = TP / (TP + FP)
    recall = TP / (TP + FN)
    
    f1_micro = 2 * np.sum(precision * recall) / (np.sum(precision) + np.sum(recall))
    
    return f1_micro



from itertools import chain, combinations
import numpy as np
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MultiLabelBinarizer, LabelEncoder
from sklearn.metrics import f1_score, confusion_matrix, precision_score, recall_score, accuracy_score
from scipy import stats
import pandas as pd

# Custom Classifier Class
# class PowersetDecisionTreeClassifier:
#     def __init__(self, max_depth=None, max_features=None, criterion='gini', max_nodes=100, min_impurity_decrease=0.0):
#         self.max_depth = max_depth
#         self.max_features = max_features
#         self.criterion = criterion
#         self.max_nodes = max_nodes
#         self.min_impurity_decrease = min_impurity_decrease
#         self.model = DecisionTreeClassifier(
#             max_depth=self.max_depth,
#             max_features=self.max_features,
#             criterion=self.criterion,
#             max_leaf_nodes=self.max_nodes,
#             min_impurity_decrease=self.min_impurity_decrease
#         )
#         self.pset = None

#     def fit(self, X_train, y_train):
#         y_powerset_train, self.pset = create_powerset_labels(y_train)
        
#         # Debug: Check the dimensions
#         print("Length of X_train:", len(X_train))
#         print("Length of y_powerset_train:", len(y_powerset_train))
        
#         self.model.fit(X_train, y_powerset_train)

    # def predict(self, X_val):
    #     y_powerset_val_pred = self.model.predict(X_val)
    #     y_val_pred = powerset_to_indicator(y_powerset_val_pred, self.pset, len(self.pset[0]))
    #     return y_val_pred

    # def predict(self, X_val):
    #     y_powerset_val_pred = self.model.predict(X_val)
    #     y_val_pred = powerset_to_indicator(y_powerset_val_pred, self.pset, self.n_classes)
    #     return y_val_pred

class PowersetDecisionTreeClassifier:
    def __init__(self, max_depth=None, max_features=None, criterion='gini'):
        self.max_depth = max_depth
        self.max_features = max_features
        self.criterion = criterion
        self.model = DecisionTreeClassifier(max_depth=self.max_depth, max_features=self.max_features, criterion=self.criterion)
        self.pset = None

    def fit(self, X_train, y_train):
        y_powerset_train, self.pset = create_powerset_labels(y_train)
        self.model.fit(X_train, y_powerset_train)

    def predict(self, X_val):
        y_powerset_val_pred = self.model.predict(X_val)
        y_val_pred = powerset_to_indicator(y_powerset_val_pred, self.pset, len(self.pset[0]))
        return y_val_pred

# Function to generate limited subsets of a set
def limited_powerset(s, max_size=4):
    return list(chain.from_iterable(combinations(s, r) for r in range(min(len(s) + 1, max_size + 1))))

# Function to create powerset labels based on unique label combinations
def create_powerset_labels(y_multi_indicator):
    unique_combinations = set()
    for labels in y_multi_indicator:
        unique_combinations.add(tuple(np.where(labels == 1)[0]))
        
    pset = list(unique_combinations)
    y_powerset = []
    
    for labels in y_multi_indicator:
        subset_index = pset.index(tuple(np.where(labels == 1)[0]))
        y_powerset.append(subset_index)
        
    return np.array(y_powerset), pset

# Function to convert powerset predictions to indicator matrix
def powerset_to_indicator(powerset_predictions, pset, n_classes):
    indicator_matrix = np.zeros((len(powerset_predictions), n_classes))
    for i, pred in enumerate(powerset_predictions):
        for label in pset[pred]:
            indicator_matrix[i, label] = 1
    return indicator_matrix

# Load data
data_dt = pd.read_csv('/home/aishani/Documents/GitHub/SMAI-Assignment-1/SMAI ASSIGNMENT 1/advertisement.csv')

# Data preprocessing
for column in data_dt.select_dtypes(include=[np.number]).columns:
    data_dt[column].fillna(data_dt[column].median(), inplace=True)
data_dt.drop_duplicates(inplace=True)
z_scores = np.abs(stats.zscore(data_dt.select_dtypes(include=[np.number])))
data_dt = data_dt[(z_scores < 3).all(axis=1)]

# Encoding categorical variables
label_encoder = LabelEncoder()
for column in data_dt.select_dtypes(include=['object']).columns:
    if column != 'labels':
        data_dt[column] = label_encoder.fit_transform(data_dt[column])

# Data Featurization
data_dt['age_income'] = data_dt['age'] * data_dt['income']
data_dt['age_children'] = data_dt['age'] * data_dt['children']
data_dt['income_children'] = data_dt['income'] * data_dt['children']
data_dt['income_purchase_amount'] = data_dt['income'] * data_dt['purchase_amount']

# Separate features and labels, and convert labels to indicator matrix
X = data_dt.drop(['labels'], axis=1)
y = data_dt['labels']
mlb = MultiLabelBinarizer()
y_indicator = mlb.fit_transform(y)

# Capture the number of classes
# n_classes = y_indicator.shape[1]

# Train-Validation-Test split
X_train_val, X_test, y_train_val, y_test = train_test_split(X, y_indicator, test_size=0.2, random_state=42)
X_train, X_val, y_train, y_val = train_test_split(X_train_val, y_train_val, test_size=0.25, random_state=42)

# Initialize and train your custom classifier
custom_classifier = PowersetDecisionTreeClassifier(max_depth=5, max_features='sqrt', criterion='gini', max_nodes=100, min_impurity_decrease=0.01)
# custom_classifier.n_classes = n_classes  # Explicitly set the number of classes
custom_classifier.fit(X_train, y_train)

# Make predictions on the validation set
y_val_pred = custom_classifier.predict(X_val)

# Calculate metrics
f1_micro = f1_score(y_val, y_val_pred, average='micro')
f1_macro = f1_score(y_val, y_val_pred, average='macro')
accuracy = accuracy_score(y_val, y_val_pred)
precision = precision_score(y_val, y_val_pred, average='micro')
recall = recall_score(y_val, y_val_pred, average='micro')
conf_matrix = confusion_matrix(y_val.argmax(axis=1), y_val_pred.argmax(axis=1))

# Print metrics
print(f"F1 Score (Micro): {f1_micro}")
print(f"F1 Score (Macro): {f1_macro}")
print(f"Accuracy: {accuracy}")
print(f"Precision: {precision}")
print(f"Recall: {recall}")
print(f"Confusion Matrix: \n{conf_matrix}")


from sklearn.model_selection import KFold

# Initialize variables to store best metrics and hyperparameters
best_f1_powerset = 0
best_hyperparameters_powerset = None
top_hyperparameters_powerset = []

kf = KFold(n_splits=5)

# Loop through all hyperparameter combinations
for max_depth, max_features, criterion in hyperparameter_combinations:
    f1_scores = []
    for train_index, val_index in kf.split(X_train_val):
        X_train, X_val = X_train_val.iloc[train_index], X_train_val.iloc[val_index]
        y_train, y_val = y_train_val[train_index], y_train_val[val_index]
        
        custom_classifier = PowersetDecisionTreeClassifier(max_depth=max_depth, max_features=max_features, criterion=criterion)
        custom_classifier.fit(X_train, y_train)
        
        y_val_pred = custom_classifier.predict(X_val)
        f1_micro = custom_f1_score(y_val, y_val_pred)
        f1_scores.append(f1_micro)
    
    avg_f1 = np.mean(f1_scores)
    print(f"Average F1 Score (Micro) for hyperparameters {max_depth, max_features, criterion}: {avg_f1}")
    
    top_hyperparameters_powerset.append((avg_f1, (max_depth, max_features, criterion)))

# Sort and take the top 3 hyperparameter sets
top_hyperparameters_powerset.sort(reverse=True)
top_hyperparameters_powerset = top_hyperparameters_powerset[:3]

print(f"Top 3 hyperparameters for Powerset Setting: {top_hyperparameters_powerset}")


" 

And my VSCode keeps crashing. Why? Give me the code which performing the similar task which would work
'''

####################################################################################################################################################################

from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score, accuracy_score, precision_score, recall_score, confusion_matrix
import numpy as np
from itertools import product

# Define custom metrics
def custom_f1_score(y_true, y_pred):
    TP = np.sum((y_true == 1) & (y_pred == 1), axis=0)
    FP = np.sum((y_true == 0) & (y_pred == 1), axis=0)
    FN = np.sum((y_true == 1) & (y_pred == 0), axis=0)
    
    precision = TP / (TP + FP)
    recall = TP / (TP + FN)
    
    f1_micro = 2 * np.sum(precision * recall) / (np.sum(precision) + np.sum(recall))
    
    return f1_micro

# Custom Classifier Class for Powerset approach
class PowersetDecisionTreeClassifier:
    def __init__(self, max_depth=None, max_features=None, criterion='gini'):
        self.max_depth = max_depth
        self.max_features = max_features
        self.criterion = criterion
        self.model = DecisionTreeClassifier(max_depth=self.max_depth, max_features=self.max_features, criterion=self.criterion)
        self.pset = None

    def fit(self, X_train, y_train):
        y_powerset_train, self.pset = self.create_powerset_labels(y_train)
        self.model.fit(X_train, y_powerset_train)

    def predict(self, X_val):
        y_powerset_val_pred = self.model.predict(X_val)
        y_val_pred = self.powerset_to_indicator(y_powerset_val_pred)
        return y_val_pred

    @staticmethod
    def create_powerset_labels(y_multi_indicator):
        unique_combinations = set(map(tuple, y_multi_indicator.tolist()))
        pset = list(unique_combinations)
        y_powerset = [pset.index(tuple(row)) for row in y_multi_indicator.tolist()]
        return np.array(y_powerset), pset

    def powerset_to_indicator(self, powerset_predictions):
        n = len(self.pset[0])
        indicator_matrix = np.zeros((len(powerset_predictions), n))
        for i, pred in enumerate(powerset_predictions):
            indicator_matrix[i] = self.pset[pred]
        return indicator_matrix




import pandas as pd
from sklearn.preprocessing import LabelEncoder, KBinsDiscretizer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MultiLabelBinarizer

data_dt = pd.read_csv("/home/aishani/Documents/GitHub/SMAI-Assignment-1/SMAI ASSIGNMENT 1/advertisement.csv")

#Below part done using chatgpt

# Initialize LabelEncoder
label_encoder = LabelEncoder()

# Encoding all categorical variables
for col in data_dt.select_dtypes(include=['object']).columns:
    if col != 'labels':  # We will handle 'labels' separately
        data_dt[col] = label_encoder.fit_transform(data_dt[col])

# Binning 
binning = KBinsDiscretizer(n_bins=5, encode='ordinal', strategy='uniform')
for col in data_dt.select_dtypes(include=['float64', 'int64']).columns:
    if col != 'labels':  
        data_dt[col] = binning.fit_transform(data_dt[[col]])

# Adding interaction terms (Product of each pair of feature)
data_dt_interaction = pd.DataFrame()
columns = data_dt.columns.tolist()
for col1 in columns:
    for col2 in columns:
        if col1 != col2 and col1 != 'labels' and col2 != 'labels':
            data_dt_interaction[f'{col1}_x_{col2}'] = data_dt[col1] * data_dt[col2]
data_dt = pd.concat([data_dt, data_dt_interaction], axis=1)

# Convert 'labels' to multi-label indicator format
mlb = MultiLabelBinarizer()
data_dt['labels'] = data_dt['labels'].apply(lambda x: x.split(' '))
labels_encoded = mlb.fit_transform(data_dt['labels'])
labels_data_dt = pd.DataFrame(labels_encoded, columns=mlb.classes_)

# Combine original data_dt with one-hot encoded labels
data_dt = data_dt.drop(columns=['labels'])
data_dt = pd.concat([data_dt, labels_data_dt], axis=1)

data_dt.head()

'''

X = data_dt.drop("labels", axis=1).values
y = data_dt["labels"].values

X = None  # Your feature matrix
y = None  # Your label matrix
'''
# Train-Validation split
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.3, random_state=42)

# Hyperparameter combinations
max_depths = [None, 5, 10]
max_features_list = ['sqrt', 'log2', None]
criterions = ['gini', 'entropy']

# Store metrics
best_f1 = 0
best_hyperparameters = None

# Iterate through hyperparameter combinations
for max_depth, max_features, criterion in product(max_depths, max_features_list, criterions):
    
    # Initialize and train classifier
    classifier = PowersetDecisionTreeClassifier(max_depth=max_depth, max_features=max_features, criterion=criterion)
    classifier.fit(X_train, y_train)
    
    # Predict on validation set
    y_val_pred = classifier.predict(X_val)
    
    # Compute metrics
    f1_micro = custom_f1_score(y_val, y_val_pred)
    f1_macro = f1_score(y_val, y_val_pred, average='macro')
    accuracy = accuracy_score(y_val, y_val_pred)
    precision = precision_score(y_val, y_val_pred, average='micro')
    recall = recall_score(y_val, y_val_pred, average='micro')
    conf_matrix = confusion_matrix(y_val.argmax(axis=1), y_val_pred.argmax(axis=1))
    
    # Update best hyperparameters based on F1 score
    if f1_micro > best_f1:
        best_f1 = f1_micro
        best_hyperparameters = (max_depth, max_features, criterion)
    
    # Print metrics for current hyperparameters
    print(f"For hyperparameters max_depth: {max_depth}, max_features: {max_features}, criterion: {criterion}")
    print(f"F1 Score (Micro): {f1_micro}")
    print(f"F1 Score (Macro): {f1_macro}")
    print(f"Accuracy: {accuracy}")
    print(f"Precision: {precision}")
    print(f"Recall: {recall}")
    print(f"Confusion Matrix: \n{conf_matrix}\n")

print(f"Best hyperparameters based on F1 score are: {best_hyperparameters}")
# Out:
# For hyperparameters max_depth: None, max_features: sqrt, criterion: gini
# F1 Score (Micro): 0.47248893735583
# F1 Score (Macro): 0.47171825809229434
# Accuracy: 0.16
# Precision: 0.45535714285714285
# Recall: 0.49038461538461536
# Confusion Matrix:
# [[56 14 12]
#  [27 14  8]
#  [13  5  1]]
#
# For hyperparameters max_depth: None, max_features: sqrt, criterion: entropy
# F1 Score (Micro): 0.5049543120946272
# F1 Score (Macro): 0.5034504590060145
# Accuracy: 0.14
# Precision: 0.4826086956521739
# Recall: 0.5336538461538461
# Confusion Matrix:
# [[44 26 12]
#  [22 20  7]
#  [ 8  9  2]]
#
# For hyperparameters max_depth: None, max_features: log2, criterion: gini
# F1 Score (Micro): 0.43407545805644543
# F1 Score (Macro): 0.43198445998446
# Accuracy: 0.08
# Precision: 0.42592592592592593
# Recall: 0.4423076923076923
# Confusion Matrix:
# [[44 27 11]
#  [30 10  9]
#  [ 7  9  3]]
#
# For hyperparameters max_depth: None, max_features: log2, criterion: entropy
# F1 Score (Micro): 0.4335447844858321
# F1 Score (Macro): 0.4190008689703626
# Accuracy: 0.1
# Precision: 0.4205607476635514
# Recall: 0.4326923076923077
# Confusion Matrix:
# [[38 22 22]
#  [28 13  8]
#  [12  4  3]]
#
# For hyperparameters max_depth: None, max_features: None, criterion: gini
# F1 Score (Micro): 0.4873594012370857
# F1 Score (Macro): 0.48517523683086594
# Accuracy: 0.11333333333333333
# Precision: 0.46320346320346323
# Recall: 0.5144230769230769
# Confusion Matrix:
# [[47 23 12]
#  [29  9 11]
#  [10  8  1]]
#
# For hyperparameters max_depth: None, max_features: None, criterion: entropy
# F1 Score (Micro): 0.5035518181925289
# F1 Score (Macro): 0.503448275862069
# Accuracy: 0.16666666666666666
# Precision: 0.47639484978540775
# Recall: 0.5336538461538461
# Confusion Matrix:
# [[53 20  9]
#  [29 13  7]
#  [12  6  1]]
#
# For hyperparameters max_depth: 5, max_features: sqrt, criterion: gini
# F1 Score (Micro): 0.41004296179421157
# F1 Score (Macro): 0.38669593486898773
# Accuracy: 0.17333333333333334
# Precision: 0.4642857142857143
# Recall: 0.375
# Confusion Matrix:
# [[51 25  6]
#  [29 18  2]
#  [10  8  1]]
#
# For hyperparameters max_depth: 5, max_features: sqrt, criterion: entropy
# F1 Score (Micro): 0.40108217978070054
# F1 Score (Macro): 0.388007641024905
# Accuracy: 0.15333333333333332
# Precision: 0.47096774193548385
# Recall: 0.35096153846153844
# Confusion Matrix:
# [[68 11  3]
#  [37 10  2]
#  [12  6  1]]
#
# For hyperparameters max_depth: 5, max_features: log2, criterion: gini
# F1 Score (Micro): 0.44761213671699124
# F1 Score (Macro): 0.4147102150285602
# Accuracy: 0.14
# Precision: 0.48554913294797686
# Recall: 0.40384615384615385
# Confusion Matrix:
# [[24 10 48]
#  [12  3 34]
#  [ 5  2 12]]
#
# For hyperparameters max_depth: 5, max_features: log2, criterion: entropy
# F1 Score (Micro): 0.4352761499465211
# F1 Score (Macro): 0.3569584438549956
# Accuracy: 0.1
# Precision: 0.45161290322580644
# Recall: 0.40384615384615385
# Confusion Matrix:
# [[22  2 58]
#  [11  2 36]
#  [ 7  1 11]]
#
# For hyperparameters max_depth: 5, max_features: None, criterion: gini
# F1 Score (Micro): 0.3615899404157437
# F1 Score (Macro): 0.35845140069562514
# Accuracy: 0.11333333333333333
# Precision: 0.45652173913043476
# Recall: 0.30288461538461536
# Confusion Matrix:
# [[38 13 31]
#  [23  9 17]
#  [11  5  3]]
#
# For hyperparameters max_depth: 5, max_features: None, criterion: entropy
# F1 Score (Micro): 0.40895793907488515
# F1 Score (Macro): 0.40381557408044416
# Accuracy: 0.12
# Precision: 0.4463276836158192
# Recall: 0.3798076923076923
# Confusion Matrix:
# [[35 20 27]
#  [20 10 19]
#  [ 9  5  5]]
#
# For hyperparameters max_depth: 10, max_features: sqrt, criterion: gini
# F1 Score (Micro): 0.4383739088949272
# F1 Score (Macro): 0.4326341548970431
# Accuracy: 0.14
# Precision: 0.4461538461538462
# Recall: 0.4182692307692308
# Confusion Matrix:
# [[56 19  7]
#  [33 10  6]
#  [11  6  2]]
#
# For hyperparameters max_depth: 10, max_features: sqrt, criterion: entropy
# F1 Score (Micro): 0.49755065493811546
# F1 Score (Macro): 0.4956183562354161
# Accuracy: 0.16
# Precision: 0.4883720930232558
# Recall: 0.5048076923076923
# Confusion Matrix:
# [[54 17 11]
#  [34 11  4]
#  [ 9  5  5]]
#
# For hyperparameters max_depth: 10, max_features: log2, criterion: gini
# F1 Score (Micro): 0.44910506012978235
# F1 Score (Macro): 0.44802531690694286
# Accuracy: 0.12
# Precision: 0.457286432160804
# Recall: 0.4375
# Confusion Matrix:
# [[37 28 17]
#  [27 14  8]
#  [ 7  7  5]]
#
# For hyperparameters max_depth: 10, max_features: log2, criterion: entropy
# F1 Score (Micro): 0.44649580235385133
# F1 Score (Macro): 0.43354782205726355
# Accuracy: 0.10666666666666667
# Precision: 0.457286432160804
# Recall: 0.4375
# Confusion Matrix:
# [[33 13 36]
#  [14 12 23]
#  [ 8  6  5]]
#
# For hyperparameters max_depth: 10, max_features: None, criterion: gini
# F1 Score (Micro): 0.47385994882523624
# F1 Score (Macro): 0.46701294170480145
# Accuracy: 0.13333333333333333
# Precision: 0.45739910313901344
# Recall: 0.49038461538461536
# Confusion Matrix:
# [[37 22 23]
#  [23 10 16]
#  [ 5  8  6]]
#
# For hyperparameters max_depth: 10, max_features: None, criterion: entropy
# F1 Score (Micro): 0.48618416349877636
# F1 Score (Macro): 0.48589118640787676
# Accuracy: 0.15333333333333332
# Precision: 0.46875
# Recall: 0.5048076923076923
# Confusion Matrix:
# [[52 14 16]
#  [27 11 11]
#  [11  5  3]]
#
# Best hyperparameters based on F1 score are: (None, 'sqrt', 'entropy')

# %%
#Below is the 3.3.1 Task 2

''' 
Source Chatgpt as similar error was being encountered as in Task 3.3.1 Task 2 and my VSCode kept crashing. I wrote the similar prompt and gave my code
to Chatgpt and it gave me the code which works

'''


import pandas as pd
from sklearn.preprocessing import LabelEncoder, KBinsDiscretizer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MultiLabelBinarizer

data_dt = pd.read_csv("/home/aishani/Documents/GitHub/SMAI-Assignment-1/SMAI ASSIGNMENT 1/advertisement.csv")

#Below part done using chatgpt

# Initialize LabelEncoder
label_encoder = LabelEncoder()

# Encoding all categorical variables
for col in data_dt.select_dtypes(include=['object']).columns:
    if col != 'labels':  # We will handle 'labels' separately
        data_dt[col] = label_encoder.fit_transform(data_dt[col])

# Binning 
binning = KBinsDiscretizer(n_bins=5, encode='ordinal', strategy='uniform')
for col in data_dt.select_dtypes(include=['float64', 'int64']).columns:
    if col != 'labels':  
        data_dt[col] = binning.fit_transform(data_dt[[col]])

# Adding interaction terms (Product of each pair of feature)
data_dt_interaction = pd.DataFrame()
columns = data_dt.columns.tolist()
for col1 in columns:
    for col2 in columns:
        if col1 != col2 and col1 != 'labels' and col2 != 'labels':
            data_dt_interaction[f'{col1}_x_{col2}'] = data_dt[col1] * data_dt[col2]
data_dt = pd.concat([data_dt, data_dt_interaction], axis=1)

# Convert 'labels' to multi-label indicator format
mlb = MultiLabelBinarizer()
data_dt['labels'] = data_dt['labels'].apply(lambda x: x.split(' '))
labels_encoded = mlb.fit_transform(data_dt['labels'])
labels_data_dt = pd.DataFrame(labels_encoded, columns=mlb.classes_)

# Combine original data_dt with one-hot encoded labels
data_dt = data_dt.drop(columns=['labels'])
data_dt = pd.concat([data_dt, labels_data_dt], axis=1)

data_dt.head()

from sklearn.multioutput import MultiOutputClassifier
from itertools import product

# Custom Classifier Class for MultiOutput Decision Tree
class MultiOutputDecisionTreeClassifier:
    def __init__(self, max_depth=None, max_features=None, criterion='gini'):
        self.max_depth = max_depth
        self.max_features = max_features
        self.criterion = criterion
        self.model = MultiOutputClassifier(DecisionTreeClassifier(max_depth=self.max_depth, 
                                                                  max_features=self.max_features, 
                                                                  criterion=self.criterion))

    def fit(self, X_train, y_train):
        self.model.fit(X_train, y_train)

    def predict(self, X_val):
        return self.model.predict(X_val)


# Define hyperparameter space
max_depths = [None, 5, 10]
max_features_options = ['sqrt', 'log2', None]
criterions = ['gini', 'entropy']

# Generate all possible combinations of hyperparameters
hyperparameter_combinations = list(product(max_depths, max_features_options, criterions))

# Initialize variables to store best metrics and hyperparameters
best_f1_micro = 0
best_f1_macro = 0
best_hyperparameters = None

# Loop through all hyperparameter combinations
for max_depth, max_features, criterion in hyperparameter_combinations:
    print(f"Training with max_depth: {max_depth}, max_features: {max_features}, criterion: {criterion}")
    
    # Initialize and train classifier
    multi_output_classifier = MultiOutputDecisionTreeClassifier(max_depth=max_depth, 
                                                                max_features=max_features, 
                                                                criterion=criterion)
    multi_output_classifier.fit(X_train, y_train)

    # Make predictions on the validation set
    y_val_pred = multi_output_classifier.predict(X_val)

    # Calculate metrics
    f1_micro = f1_score(y_val, y_val_pred, average='micro')
    f1_macro = f1_score(y_val, y_val_pred, average='macro')
    
    print(f"F1 Score (Micro): {f1_micro}")
    print(f"F1 Score (Macro): {f1_macro}")
    
    # Update best metrics and hyperparameters
    if f1_micro > best_f1_micro:
        best_f1_micro = f1_micro
        best_f1_macro = f1_macro
        best_hyperparameters = (max_depth, max_features, criterion)

# Print best metrics and hyperparameters
print(f"Best F1 Score (Micro): {best_f1_micro}")
print(f"Best F1 Score (Macro): {best_f1_macro}")
print(f"Best Hyperparameters: {best_hyperparameters}")

# Train the final model using the best hyperparameters
final_model = MultiOutputDecisionTreeClassifier(*best_hyperparameters)
final_model.fit(X_train, y_train)

# Make predictions on the validation set using the final model
y_val_pred = final_model.predict(X_val)

# Calculate metrics for the final model
accuracy = accuracy_score(y_val, y_val_pred)
precision = precision_score(y_val, y_val_pred, average='micro')
recall = recall_score(y_val, y_val_pred, average='micro')
conf_matrix = confusion_matrix(y_val.argmax(axis=1), y_val_pred.argmax(axis=1))

# Print metrics for the final model
print(f"Accuracy: {accuracy}")
print(f"Precision: {precision}")
print(f"Recall: {recall}")
print(f"Confusion Matrix: \n{conf_matrix}")
# Out:
# Training with max_depth: None, max_features: sqrt, criterion: gini
# F1 Score (Micro): 0.4743276283618582
# F1 Score (Macro): 0.47385030772285086
# Training with max_depth: None, max_features: sqrt, criterion: entropy
# F1 Score (Micro): 0.4697336561743341
# F1 Score (Macro): 0.47028793295659854
# Training with max_depth: None, max_features: log2, criterion: gini
# F1 Score (Micro): 0.5245901639344263
# F1 Score (Macro): 0.5220034445840898
# Training with max_depth: None, max_features: log2, criterion: entropy
# F1 Score (Micro): 0.47663551401869153
# F1 Score (Macro): 0.47561078529439027
# Training with max_depth: None, max_features: None, criterion: gini
# F1 Score (Micro): 0.4564705882352941
# F1 Score (Macro): 0.4569415964152806
# Training with max_depth: None, max_features: None, criterion: entropy
# F1 Score (Micro): 0.4316546762589928
# F1 Score (Macro): 0.43076920014947034
# Training with max_depth: 5, max_features: sqrt, criterion: gini
# F1 Score (Micro): 0.3705882352941176
# F1 Score (Macro): 0.33934515514833663
# Training with max_depth: 5, max_features: sqrt, criterion: entropy
# F1 Score (Micro): 0.4438902743142145
# F1 Score (Macro): 0.4431381936502025
# Training with max_depth: 5, max_features: log2, criterion: gini
# F1 Score (Micro): 0.46741573033707867
# F1 Score (Macro): 0.46861352728225797
# Training with max_depth: 5, max_features: log2, criterion: entropy
# F1 Score (Micro): 0.4911504424778761
# F1 Score (Macro): 0.481623741689722
# Training with max_depth: 5, max_features: None, criterion: gini
# F1 Score (Micro): 0.4911504424778761
# F1 Score (Macro): 0.49014035994144495
# Training with max_depth: 5, max_features: None, criterion: entropy
# F1 Score (Micro): 0.4520547945205479
# F1 Score (Macro): 0.4413813546761524
# Training with max_depth: 10, max_features: sqrt, criterion: gini
# F1 Score (Micro): 0.4600484261501211
# F1 Score (Macro): 0.4574781472610197
# Training with max_depth: 10, max_features: sqrt, criterion: entropy
# F1 Score (Micro): 0.5110132158590309
# F1 Score (Macro): 0.49702045920737775
# Training with max_depth: 10, max_features: log2, criterion: gini
# F1 Score (Micro): 0.4582338902147972
# F1 Score (Macro): 0.45805058081194616
# Training with max_depth: 10, max_features: log2, criterion: entropy
# F1 Score (Micro): 0.4955752212389381
# F1 Score (Macro): 0.4933896263819537
# Training with max_depth: 10, max_features: None, criterion: gini
# F1 Score (Micro): 0.48372093023255813
# F1 Score (Macro): 0.483928011180514
# Training with max_depth: 10, max_features: None, criterion: entropy
# F1 Score (Micro): 0.4723404255319149
# F1 Score (Macro): 0.4691067620287221
# Best F1 Score (Micro): 0.5245901639344263
# Best F1 Score (Macro): 0.5220034445840898
# Best Hyperparameters: (None, 'log2', 'gini')
# Accuracy: 0.12666666666666668
# Precision: 0.46261682242990654
# Recall: 0.47596153846153844
# Confusion Matrix:
# [[51 19 12]
#  [31 11  7]
#  [ 9  9  1]]

# %% [markdown]
# Hyperparameter Tuning

# %%
#Below is implementation of 3.4.1 for Powerset setting (all tasks)

from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score, accuracy_score, precision_score, recall_score, confusion_matrix
import numpy as np
from itertools import product


# Define custom metrics
def custom_f1_score(y_true, y_pred):
    TP = np.sum((y_true == 1) & (y_pred == 1), axis=0)
    FP = np.sum((y_true == 0) & (y_pred == 1), axis=0)
    FN = np.sum((y_true == 1) & (y_pred == 0), axis=0)

    precision = TP / (TP + FP)
    if (TP.all() == 0 and FP.all()==0):
        precision = np.zeros_like(TP)
    recall = TP / (TP + FN)
    if (TP.all() == 0 and FN.all()==0):
        recall = np.zeros_like(TP)
    
    if( TP.all() == 0 and FN.all()==0  and FP.all()==0 ):
        return 0
    
    f1_micro = 2 * np.sum(precision * recall) / (np.sum(precision) + np.sum(recall))
    
    
    
    return f1_micro

# Custom Classifier Class for Powerset approach
class PowersetDecisionTreeClassifier:
    def __init__(self, max_depth=None, max_features=None, criterion='gini'):
        self.max_depth = max_depth
        self.max_features = max_features
        self.criterion = criterion
        self.model = DecisionTreeClassifier(max_depth=self.max_depth, max_features=self.max_features, criterion=self.criterion)
        self.pset = None

    def fit(self, X_train, y_train):
        y_powerset_train, self.pset = self.create_powerset_labels(y_train)
        self.model.fit(X_train, y_powerset_train)

    def predict(self, X_val):
        y_powerset_val_pred = self.model.predict(X_val)
        y_val_pred = self.powerset_to_indicator(y_powerset_val_pred)
        return y_val_pred

    @staticmethod
    def create_powerset_labels(y_multi_indicator):
        unique_combinations = set(map(tuple, y_multi_indicator.tolist()))
        pset = list(unique_combinations)
        y_powerset = [pset.index(tuple(row)) for row in y_multi_indicator.tolist()]
        return np.array(y_powerset), pset

    def powerset_to_indicator(self, powerset_predictions):
        n = len(self.pset[0])
        indicator_matrix = np.zeros((len(powerset_predictions), n))
        for i, pred in enumerate(powerset_predictions):
            indicator_matrix[i] = self.pset[pred]
        return indicator_matrix


import pandas as pd
from sklearn.preprocessing import LabelEncoder, KBinsDiscretizer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MultiLabelBinarizer

data_dt = pd.read_csv("/home/aishani/Documents/GitHub/SMAI-Assignment-1/SMAI ASSIGNMENT 1/advertisement.csv")

#Below part done using chatgpt

# Initialize LabelEncoder
label_encoder = LabelEncoder()

# Encoding all categorical variables
for col in data_dt.select_dtypes(include=['object']).columns:
    if col != 'labels':  # We will handle 'labels' separately
        data_dt[col] = label_encoder.fit_transform(data_dt[col])

# Binning 
binning = KBinsDiscretizer(n_bins=5, encode='ordinal', strategy='uniform')
for col in data_dt.select_dtypes(include=['float64', 'int64']).columns:
    if col != 'labels':  
        data_dt[col] = binning.fit_transform(data_dt[[col]])

# Adding interaction terms (Product of each pair of feature)
data_dt_interaction = pd.DataFrame()
columns = data_dt.columns.tolist()
for col1 in columns:
    for col2 in columns:
        if col1 != col2 and col1 != 'labels' and col2 != 'labels':
            data_dt_interaction[f'{col1}_x_{col2}'] = data_dt[col1] * data_dt[col2]
data_dt = pd.concat([data_dt, data_dt_interaction], axis=1)

# Convert 'labels' to multi-label indicator format
mlb = MultiLabelBinarizer()
data_dt['labels'] = data_dt['labels'].apply(lambda x: x.split(' '))
labels_encoded = mlb.fit_transform(data_dt['labels'])
labels_data_dt = pd.DataFrame(labels_encoded, columns=mlb.classes_)

# Combine original data_dt with one-hot encoded labels
data_dt = data_dt.drop(columns=['labels'])
data_dt = pd.concat([data_dt, labels_data_dt], axis=1)

data_dt.head()

# Train-Validation split
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.3, random_state=42)

# Hyperparameter combinations
# max_depths = [None, 5, 10]
# max_features_list = ['sqrt', 'log2', None]
# criterions = ['gini', 'entropy']

# Store metrics
best_f1 = 0
best_hyperparameters = None

# Iterate through hyperparameter combinations
for max_depth, max_features, criterion in product(max_depths, max_features_list, criterions):
    
    # Initialize and train classifier
    classifier = PowersetDecisionTreeClassifier(max_depth=max_depth, max_features=max_features, criterion=criterion)
    classifier.fit(X_train, y_train)
    
    # Predict on validation set
    y_val_pred = classifier.predict(X_val)
    
    # Compute metrics
    f1_micro = custom_f1_score(y_val, y_val_pred)
    f1_macro = f1_score(y_val, y_val_pred, average='macro')
    accuracy = accuracy_score(y_val, y_val_pred)
    precision = precision_score(y_val, y_val_pred, average='micro')
    recall = recall_score(y_val, y_val_pred, average='micro')
    conf_matrix = confusion_matrix(y_val.argmax(axis=1), y_val_pred.argmax(axis=1))
    
    # Update best hyperparameters based on F1 score
    if f1_micro > best_f1:
        best_f1 = f1_micro
        best_hyperparameters = (max_depth, max_features, criterion)
    
    # Print metrics for current hyperparameters
    # print(f"For hyperparameters max_depth: {max_depth}, max_features: {max_features}, criterion: {criterion}")
    # print(f"F1 Score (Micro): {f1_micro}")
    # print(f"F1 Score (Macro): {f1_macro}")
    # print(f"Accuracy: {accuracy}")
    # print(f"Precision: {precision}")
    # print(f"Recall: {recall}")
    # print(f"Confusion Matrix: \n{conf_matrix}\n")

# print(f"Best hyperparameters based on F1 score are: {best_hyperparameters}")

from sklearn.model_selection import KFold

# Define hyperparameter space
criterions = ['gini', 'entropy']
max_depths = [3, 5, 10, 20, 30]
max_features_list = [3, 5, 7, 9, 11]

print(f"For hyperparameters max_depth: {max_depth}, max_features: {max_features}, criterion: {criterion}")
print(f"F1 Score (Micro): {f1_micro}")
print(f"F1 Score (Macro): {f1_macro}")
print(f"Accuracy: {accuracy}")
print(f"Precision: {precision}")
print(f"Recall: {recall}")
print(f"Confusion Matrix: \n{conf_matrix}\n")

#  Initialize variables to store metrics and hyperparameters
metrics_powerset = []

# Generate all possible combinations of hyperparameters
hyperparameter_combinations = list(product(max_depths, max_features_list, criterions))

# Initialize variables to store best metrics and hyperparameters
best_f1_powerset = 0

best_hyperparameters_powerset = None


top_hyperparameters_powerset = []


kf = KFold(n_splits=5)

# Loop through all hyperparameter combinations
for max_depth, max_features, criterion in hyperparameter_combinations:
    f1_scores_powerset = []
    
    
    for train_index, val_index in kf.split(X_train):
        X_train_fold, X_val_fold = X_train[train_index], X_train[val_index]
        y_train_fold, y_val_fold = y_train[train_index], y_train[val_index]
        
        # Powerset Setting
        # custom_classifier = PowersetDecisionTreeClassifier(max_depth=max_depth, max_features=max_features, criterion=criterion)
        # custom_classifier.fit(X_train_fold, y_train_fold)
        # y_val_pred = custom_classifier.predict(X_val_fold)
        # f1_micro = custom_f1_score(y_val_fold, y_val_pred)
        # f1_scores_powerset.append(f1_micro)

        custom_classifier = PowersetDecisionTreeClassifier(max_depth=max_depth, max_features=max_features, criterion=criterion)
        custom_classifier.fit(X_train_fold, y_train_fold)
        y_val_pred = custom_classifier.predict(X_val_fold)
        f1_micro = custom_f1_score(y_val_fold, y_val_pred)
        f1_macro = f1_score(y_val_fold, y_val_pred, average='macro')
        accuracy = accuracy_score(y_val_fold, y_val_pred)
        precision = precision_score(y_val_fold, y_val_pred, average='micro', zero_division=0)
        recall = recall_score(y_val_fold, y_val_pred, average='micro', zero_division=0)
        conf_matrix = confusion_matrix(y_val_fold.argmax(axis=1), y_val_pred.argmax(axis=1))
        
        f1_scores_powerset.append({
            'f1_micro': f1_micro,
            'f1_macro': f1_macro,
            'accuracy': accuracy,
            'precision': precision,
            'recall': recall,
            'conf_matrix': conf_matrix,
            'params': (max_depth, max_features, criterion)
        })

# avg_f1_powerset = np.mean(f1_scores_powerset)
    metrics_powerset.append(f1_scores_powerset)

# Sort and take the top 3 hyperparameter sets based on average F1-micro score
top_hyperparameters_powerset = sorted(metrics_powerset, key=lambda x: np.mean([y['f1_micro'] for y in x]), reverse=True)[:3]

# Reporting
print("Top 3 Hyperparameters and their metrics for Powerset Setting:")
for rank, metric_list in enumerate(top_hyperparameters_powerset, 1):
    avg_f1_micro = np.mean([x['f1_micro'] for x in metric_list])
    print(f"Rank {rank} - Params: {metric_list[0]['params']} - Avg F1 Micro: {avg_f1_micro}")

# K-Fold validation for the best models
best_model_metrics_powerset = top_hyperparameters_powerset[0]

print("K-Fold Validation Metrics for the best model in Powerset Setting:")

best_f1_micro_across_folds =[]
best_f1_macro_across_folds =[]
best_accuracy_across_folds =[]
best_precision_across_folds =[]
best_recall_across_folds =[]

for fold, metrics in enumerate(best_model_metrics_powerset):
    best_f1_macro_across_folds.append(metrics['f1_macro'])
    best_f1_micro_across_folds.append(metrics['f1_micro'])
    best_accuracy_across_folds.append(metrics['accuracy'])
    best_precision_across_folds.append(metrics['precision'])
    best_recall_across_folds.append(metrics['recall'])


    print(f"Fold {fold + 1}: F1 Micro: {metrics['f1_micro']}, F1 Macro: {metrics['f1_macro']}, Accuracy: {metrics['accuracy']}, Precision: {metrics['precision']} , Recall: {metrics['recall']},Confusion Matrix: \n{metrics['conf_matrix']}, ")

# print(f"Average F1 Score (Micro) for hyperparameters {max_depth, max_features, criterion} in Powerset Setting: {avg_f1_powerset}")

# top_hyperparameters_powerset.append((avg_f1_powerset, (max_depth, max_features, criterion)))

# Sort and take the top 3 hyperparameter sets
# top_hyperparameters_powerset.sort(reverse=True)

# top_hyperparameters_powerset = top_hyperparameters_powerset[:3]

# print(f"Top 3 hyperparameters for Powerset Setting: {top_hyperparameters_powerset}")
# Out:
# For hyperparameters max_depth: 10, max_features: None, criterion: entropy
# F1 Score (Micro): 0.532585412374136
# F1 Score (Macro): 0.5321547703121917
# Accuracy: 0.18666666666666668
# Precision: 0.5043103448275862
# Recall: 0.5625
# Confusion Matrix:
# [[60 18  4]
#  [24 13 12]
#  [10  7  2]]
# /tmp/ipykernel_14268/2986789736.py:16: RuntimeWarning: invalid value encountered in divide
#   precision = TP / (TP + FP)
# /tmp/ipykernel_14268/2986789736.py:16: RuntimeWarning: invalid value encountered in divide
#   precision = TP / (TP + FP)
# /tmp/ipykernel_14268/2986789736.py:16: RuntimeWarning: invalid value encountered in divide
#   precision = TP / (TP + FP)
# /tmp/ipykernel_14268/2986789736.py:16: RuntimeWarning: invalid value encountered in divide
#   precision = TP / (TP + FP)
# Top 3 Hyperparameters and their metrics for Powerset Setting:
# Rank 1 - Params: (10, 7, 'entropy') - Avg F1 Micro: 0.5101403918106944
# Rank 2 - Params: (20, 3, 'entropy') - Avg F1 Micro: 0.5086820213217995
# Rank 3 - Params: (30, 7, 'gini') - Avg F1 Micro: 0.5061549066221598
# K-Fold Validation Metrics for the best model in Powerset Setting:
# Fold 1: F1 Micro: 0.4975180143265461, F1 Macro: 0.4884436866534054, Accuracy: 0.1, Precision: 0.46226415094339623 , Recall: 0.5212765957446809,Confusion Matrix:
# [[28  6  6]
#  [ 9  4  3]
#  [ 7  5  2]],
# Fold 2: F1 Micro: 0.49656307154560414, F1 Macro: 0.4891067538126362, Accuracy: 0.11428571428571428, Precision: 0.4854368932038835 , Recall: 0.49504950495049505,Confusion Matrix:
# [[23 10 11]
#  [ 9  6  5]
#  [ 3  2  1]],
# Fold 3: F1 Micro: 0.5134485353224926, F1 Macro: 0.511976911976912, Accuracy: 0.14285714285714285, Precision: 0.5094339622641509 , Recall: 0.5192307692307693,Confusion Matrix:
# [[23  9  6]
#  [ 9  6  2]
#  [ 9  3  3]],
# Fold 4: F1 Micro: 0.5404592958672441, F1 Macro: 0.536799070600651, Accuracy: 0.1, Precision: 0.5294117647058824 , Recall: 0.5454545454545454,Confusion Matrix:
# [[23 10  7]
#  [10  5  1]
#  [ 8  4  2]],
# Fold 5: F1 Micro: 0.502713041991585, F1 Macro: 0.5014879132526192, Accuracy: 0.08571428571428572, Precision: 0.5048543689320388 , Recall: 0.5,Confusion Matrix:
# [[21 18  8]
#  [ 8  4  1]
#  [ 4  4  2]],

# %%
#Task 3.4.1 for MultiOutput Setting (all tasks)

from sklearn.multioutput import MultiOutputClassifier
from itertools import product
from sklearn.model_selection import KFold


import pandas as pd
from sklearn.preprocessing import LabelEncoder, KBinsDiscretizer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MultiLabelBinarizer

data_dt = pd.read_csv("/home/aishani/Documents/GitHub/SMAI-Assignment-1/SMAI ASSIGNMENT 1/advertisement.csv")

#Below part done using chatgpt

# Initialize LabelEncoder
label_encoder = LabelEncoder()

# Encoding all categorical variables
for col in data_dt.select_dtypes(include=['object']).columns:
    if col != 'labels':  # We will handle 'labels' separately
        data_dt[col] = label_encoder.fit_transform(data_dt[col])

# Binning 
binning = KBinsDiscretizer(n_bins=5, encode='ordinal', strategy='uniform')
for col in data_dt.select_dtypes(include=['float64', 'int64']).columns:
    if col != 'labels':  
        data_dt[col] = binning.fit_transform(data_dt[[col]])

# Adding interaction terms (Product of each pair of feature)
data_dt_interaction = pd.DataFrame()
columns = data_dt.columns.tolist()
for col1 in columns:
    for col2 in columns:
        if col1 != col2 and col1 != 'labels' and col2 != 'labels':
            data_dt_interaction[f'{col1}_x_{col2}'] = data_dt[col1] * data_dt[col2]
data_dt = pd.concat([data_dt, data_dt_interaction], axis=1)

# Convert 'labels' to multi-label indicator format
mlb = MultiLabelBinarizer()
data_dt['labels'] = data_dt['labels'].apply(lambda x: x.split(' '))
labels_encoded = mlb.fit_transform(data_dt['labels'])
labels_data_dt = pd.DataFrame(labels_encoded, columns=mlb.classes_)

# Combine original data_dt with one-hot encoded labels
data_dt = data_dt.drop(columns=['labels'])
data_dt = pd.concat([data_dt, labels_data_dt], axis=1)

data_dt.head()

# Custom Classifier Class for MultiOutput Decision Tree
class MultiOutputDecisionTreeClassifier:
    def __init__(self, max_depth=None, max_features=None, criterion='gini'):
        self.max_depth = max_depth
        self.max_features = max_features
        self.criterion = criterion
        self.model = MultiOutputClassifier(DecisionTreeClassifier(max_depth=self.max_depth, 
                                                                  max_features=self.max_features, 
                                                                  criterion=self.criterion))

    def fit(self, X_train, y_train):
        self.model.fit(X_train, y_train)

    def predict(self, X_val):
        return self.model.predict(X_val)


# Define hyperparameter space
max_depths = [None, 5, 10]
max_features_options = ['sqrt', 'log2', None]
criterions = ['gini', 'entropy']

# Generate all possible combinations of hyperparameters
hyperparameter_combinations = list(product(max_depths, max_features_options, criterions))

# Initialize variables to store best metrics and hyperparameters
best_f1_micro = 0
best_f1_macro = 0
best_hyperparameters = None

# Loop through all hyperparameter combinations
for max_depth, max_features, criterion in hyperparameter_combinations:
    print(f"Training with max_depth: {max_depth}, max_features: {max_features}, criterion: {criterion}")
    
    # Initialize and train classifier
    multi_output_classifier = MultiOutputDecisionTreeClassifier(max_depth=max_depth, 
                                                                max_features=max_features, 
                                                                criterion=criterion)
    multi_output_classifier.fit(X_train, y_train)

    # Make predictions on the validation set
    y_val_pred = multi_output_classifier.predict(X_val)

    # Calculate metrics
    f1_micro = f1_score(y_val, y_val_pred, average='micro')
    f1_macro = f1_score(y_val, y_val_pred, average='macro')
    
    # print(f"F1 Score (Micro): {f1_micro}")
    # print(f"F1 Score (Macro): {f1_macro}")
    
    # Update best metrics and hyperparameters
    if f1_micro > best_f1_micro:
        best_f1_micro = f1_micro
        best_f1_macro = f1_macro
        best_hyperparameters = (max_depth, max_features, criterion)

# Print best metrics and hyperparameters
# print(f"Best F1 Score (Micro): {best_f1_micro}")
# print(f"Best F1 Score (Macro): {best_f1_macro}")
# print(f"Best Hyperparameters: {best_hyperparameters}")

# Train the final model using the best hyperparameters
final_model = MultiOutputDecisionTreeClassifier(*best_hyperparameters)
final_model.fit(X_train, y_train)

# Make predictions on the validation set using the final model
y_val_pred = final_model.predict(X_val)

# Calculate metrics for the final model
accuracy = accuracy_score(y_val, y_val_pred)
precision = precision_score(y_val, y_val_pred, average='micro')
recall = recall_score(y_val, y_val_pred, average='micro')
conf_matrix = confusion_matrix(y_val.argmax(axis=1), y_val_pred.argmax(axis=1))

# Print metrics for the final model
# print(f"Accuracy: {accuracy}")
# print(f"Precision: {precision}")
# print(f"Recall: {recall}")
# print(f"Confusion Matrix: \n{conf_matrix}")

from sklearn.model_selection import KFold

# Define hyperparameter space as required in task
criterions = ['gini', 'entropy']
max_depths = [3, 5, 10, 20, 30]
max_features_list = [3, 5, 7, 9, 11]

print(f"For hyperparameters max_depth: {max_depth}, max_features: {max_features}, criterion: {criterion}")
print(f"F1 Score (Micro): {f1_micro}")
print(f"F1 Score (Macro): {f1_macro}")
print(f"Accuracy: {accuracy}")
print(f"Precision: {precision}")
print(f"Recall: {recall}")
print(f"Confusion Matrix: \n{conf_matrix}\n")

# Initialize variables to store metrics and hyperparameters
metrics_multioutput = []

# Generate all possible combinations of hyperparameters
hyperparameter_combinations = list(product(max_depths, max_features_list, criterions))

# Initialize variables to store best metrics and hyperparameters

best_f1_multioutput = 0

best_hyperparameters_multioutput = None


top_hyperparameters_multioutput = []

kf = KFold(n_splits=5)

# Loop through all hyperparameter combinations
for max_depth, max_features, criterion in hyperparameter_combinations:
   
    f1_scores_multioutput = []
    
    for train_index, val_index in kf.split(X_train):
        X_train_fold, X_val_fold = X_train[train_index], X_train[val_index]
        y_train_fold, y_val_fold = y_train[train_index], y_train[val_index]
        
        
        
        # MultiOutput Setting
    #     multi_output_classifier = MultiOutputDecisionTreeClassifier(max_depth=max_depth, max_features=max_features, criterion=criterion)
    #     multi_output_classifier.fit(X_train_fold, y_train_fold)
    #     y_val_pred = multi_output_classifier.predict(X_val_fold)
    #     f1_micro = f1_score(y_val_fold, y_val_pred, average='micro')
    #     f1_scores_multioutput.append(f1_micro)
    
   
    # avg_f1_multioutput = np.mean(f1_scores_multioutput)
    
    
    # print(f"Average F1 Score (Micro) for hyperparameters {max_depth, max_features, criterion} in MultiOutput Setting: {avg_f1_multioutput}")
    
    
    # top_hyperparameters_multioutput.append((avg_f1_multioutput, (max_depth, max_features, criterion)))

# Sort and take the top 3 hyperparameter sets

# top_hyperparameters_multioutput.sort(reverse=True)


# top_hyperparameters_multioutput = top_hyperparameters_multioutput[:3]


# print(f"Top 3 hyperparameters for MultiOutput Setting: {top_hyperparameters_multioutput}")

        multi_output_classifier = MultiOutputDecisionTreeClassifier(max_depth=max_depth, max_features=max_features, criterion=criterion)
        multi_output_classifier.fit(X_train_fold, y_train_fold)
        y_val_pred = multi_output_classifier.predict(X_val_fold)
        f1_micro = f1_score(y_val_fold, y_val_pred, average='micro')
        f1_macro = f1_score(y_val_fold, y_val_pred, average='macro')
        accuracy = accuracy_score(y_val_fold, y_val_pred)
        precision = precision_score(y_val_fold, y_val_pred, average='micro')
        recall = recall_score(y_val_fold, y_val_pred, average='micro')
        conf_matrix = confusion_matrix(y_val_fold.argmax(axis=1), y_val_pred.argmax(axis=1))
        
        f1_scores_multioutput.append({
            'f1_micro': f1_micro,
            'f1_macro': f1_macro,
            'accuracy': accuracy,
            'precision': precision,
            'recall': recall,
            'conf_matrix': conf_matrix,
            'params': (max_depth, max_features, criterion)
        })
    
    
    metrics_multioutput.append(f1_scores_multioutput)

# Sort and take the top 3 hyperparameter sets based on average F1-micro score

top_hyperparameters_multioutput = sorted(metrics_multioutput, key=lambda x: np.mean([y['f1_micro'] for y in x]), reverse=True)[:3]

# Reporting

print("Top 3 Hyperparameters and their metrics for MultiOutput Setting:")
for rank, metric_list in enumerate(top_hyperparameters_multioutput, 1):
    avg_f1_micro = np.mean([x['f1_micro'] for x in metric_list])
    print(f"Rank {rank} - Params: {metric_list[0]['params']} - Avg F1 Micro: {avg_f1_micro}")

# K-Fold validation for the best models

best_model_metrics_multioutput = top_hyperparameters_multioutput[0]


print("K-Fold Validation Metrics for the best model in MultiOutput Setting:")
for fold, metrics in enumerate(best_model_metrics_multioutput):
    print(f"Fold {fold + 1}: F1 Micro: {metrics['f1_micro']}, F1 Macro: {metrics['f1_macro']}, Accuracy: {metrics['accuracy']}, Confusion Matrix: \n{metrics['conf_matrix']}")
# Out:
# Training with max_depth: None, max_features: sqrt, criterion: gini
# Training with max_depth: None, max_features: sqrt, criterion: entropy
# Training with max_depth: None, max_features: log2, criterion: gini
# Training with max_depth: None, max_features: log2, criterion: entropy
# Training with max_depth: None, max_features: None, criterion: gini
# Training with max_depth: None, max_features: None, criterion: entropy
# Training with max_depth: 5, max_features: sqrt, criterion: gini
# Training with max_depth: 5, max_features: sqrt, criterion: entropy
# Training with max_depth: 5, max_features: log2, criterion: gini
# Training with max_depth: 5, max_features: log2, criterion: entropy
# Training with max_depth: 5, max_features: None, criterion: gini
# Training with max_depth: 5, max_features: None, criterion: entropy
# Training with max_depth: 10, max_features: sqrt, criterion: gini
# Training with max_depth: 10, max_features: sqrt, criterion: entropy
# Training with max_depth: 10, max_features: log2, criterion: gini
# Training with max_depth: 10, max_features: log2, criterion: entropy
# Training with max_depth: 10, max_features: None, criterion: gini
# Training with max_depth: 10, max_features: None, criterion: entropy
# For hyperparameters max_depth: 10, max_features: None, criterion: entropy
# F1 Score (Micro): 0.45739910313901344
# F1 Score (Macro): 0.4491877226272512
# Accuracy: 0.14
# Precision: 0.47150259067357514
# Recall: 0.4375
# Confusion Matrix:
# [[41 27 14]
#  [32  9  8]
#  [ 9  3  7]]
#
# Top 3 Hyperparameters and their metrics for MultiOutput Setting:
# Rank 1 - Params: (20, 5, 'gini') - Avg F1 Micro: 0.5261974309643369
# Rank 2 - Params: (3, 5, 'entropy') - Avg F1 Micro: 0.514977365914169
# Rank 3 - Params: (10, 11, 'gini') - Avg F1 Micro: 0.5142487242405502
# K-Fold Validation Metrics for the best model in MultiOutput Setting:
# Fold 1: F1 Micro: 0.594059405940594, F1 Macro: 0.5941988998668629, Accuracy: 0.22857142857142856, Confusion Matrix:
# [[26  7  7]
#  [ 7  5  4]
#  [ 8  1  5]]
# Fold 2: F1 Micro: 0.5123152709359606, F1 Macro: 0.5095355095355095, Accuracy: 0.17142857142857143, Confusion Matrix:
# [[32  8  4]
#  [10  5  5]
#  [ 5  0  1]]
# Fold 3: F1 Micro: 0.46766169154228854, F1 Macro: 0.46103988603988605, Accuracy: 0.07142857142857142, Confusion Matrix:
# [[20 10  8]
#  [12  2  3]
#  [10  4  1]]
# Fold 4: F1 Micro: 0.4907407407407407, F1 Macro: 0.49058736576670575, Accuracy: 0.07142857142857142, Confusion Matrix:
# [[22 12  6]
#  [ 9  2  5]
#  [ 8  4  2]]
# Fold 5: F1 Micro: 0.5662100456621004, F1 Macro: 0.556728185918615, Accuracy: 0.17142857142857143, Confusion Matrix:
# [[34  4  9]
#  [ 6  6  1]
#  [ 9  0  1]]
